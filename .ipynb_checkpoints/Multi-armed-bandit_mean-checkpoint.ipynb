# %%
import glob
import cv2
import math 
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import json
import datetime
import matplotlib.image as mpimg
import random
import time
import copy


# %matplotlib inline
import pandas as pd
import numpy as np
np.random.bit_generator = np.random._bit_generator

from tensorflow.keras.preprocessing import image
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, Conv2D, Dropout, Flatten,MaxPooling2D, concatenate, UpSampling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.models import Model,load_model
#from keras_segmentation.models.model_utils import get_segmentation_mode
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
#from tensorflow.contrib import distributions

# from tensorflow.keras.utils import np_utils
from skimage.transform import resize
from datetime import datetime
from mpl_toolkits.mplot3d import Axes3D
from imgaug import augmenters as iaa
from imgaug.augmentables.segmaps import SegmentationMapsOnImage

# %%
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.gpu_options.per_process_gpu_memory_fraction = 0.6
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device

# %%
def get_img_name(path):
    names = glob.glob(f"{path}*")
    names.sort()
    return names

def img_process(img):
    img = cv2.resize(img, (IMG_WIDTH,IMG_HEIGHT)) #640x480, 320x240
    return img

def show_seg_on_img(img, mask, alpha=0.5):
    #img = img.astype(np.float64)*255
    #img = cv2.normalize(img, None, 0, 255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8UC3)
    #mask = mask.astype(np.float64)*255
    #mask = cv2.normalize(mask, None, 0, 255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8UC3)
    
    img_mask = cv2.addWeighted(mask, alpha, img, 0.5, 0)
    return img_mask 

def compare_img(img1, img2, title1 = 'Image 1', title2 = 'Image 2'):
    #img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    #img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
    
    fig = plt.figure(figsize=(16, 12))
    a = fig.add_subplot(1,2,1)
    imgplot = plt.imshow(img1)
    a.set_title(title1)

    a = fig.add_subplot(1, 2, 2)
    imgplot = plt.imshow(img2)

    
def predictions_and_uncetrenty(model, T, img):
    
    # shape: (T, (H, W), C)
    predictions = np.array([model.predict(img) for _ in range(T)])
    
    # shape: ((H, W), C)
    prediction_probabilities = np.mean(predictions, axis=tuple(range(img.ndim-2)))
   
    # shape: (H, W)
    #prediction_variances = np.apply_along_axis(predictive_entropy, axis=2, arr=prediction_probabilities)
    prediction_std = np.std(predictions, axis=tuple(range(img.ndim-2)))
    prediction_mask = (prediction_probabilities==prediction_probabilities.max(axis=2, keepdims=1)).astype(np.uint8)
    prediction_std = prediction_std * prediction_mask
    prediction_std = np.amax(prediction_std, axis=2)
    
    prediction_mean = prediction_probabilities * prediction_mask
    prediction_mean = np.amax(prediction_mean, axis=2)
    return prediction_mask, prediction_mean ,prediction_std

'''
If we are not using image augmentation we need to reduce the channels.
'''
def labels_to_maskes_reduce(img_label, color_id_map, num_channels):
    num_objects = len(color_id_map.keys())
    
    height = img_label.shape[0]
    width = img_label.shape[1]

    channels = np.zeros((height, width, num_channels), dtype=np.uint8)
    
    for key, value in color_id_map.items():
        mask = (img_label == value[1]).all(-1)

        channels[..., value[0]] = np.logical_or(channels[:,:, value[0]], mask)


    return channels

def maskes_to_labels(maskes):
    #denne maa muligens fjernes
    maskes = (maskes==maskes.max(axis=2, keepdims=1)).astype(np.uint8)
    labels = np.zeros((maskes.shape[0], maskes.shape[1], 3), dtype=np.uint8)
        
    for key, value in classes_cc.items():
        mask = maskes[..., key]
        labels = labels + mask[..., None] * value
    
    return labels 

def predictions_and_uncetrenty(model, T, img):
    
    # shape: (T, (H, W), C)
    predictions = np.array([model.predict(img) for _ in range(T)])
    
    # shape: ((H, W), C)
    prediction_probabilities = np.mean(predictions, axis=tuple(range(img.ndim-2)))
   
    # shape: (H, W)
    #prediction_variances = np.apply_along_axis(predictive_entropy, axis=2, arr=prediction_probabilities)
    prediction_std = np.std(predictions, axis=tuple(range(img.ndim-2)))
    prediction_mask = (prediction_probabilities==prediction_probabilities.max(axis=2, keepdims=1)).astype(np.uint8)
    prediction_std = prediction_std * prediction_mask
    prediction_std = np.amax(prediction_std, axis=2)
    
    prediction_mean = prediction_probabilities * prediction_mask
    prediction_mean = np.amax(prediction_mean, axis=2)
    return prediction_mask, prediction_mean ,prediction_std

# %%
def batch_generator(image_paths, label_path, color_labels, index_list, batch_size, index=0):
    
    
    index = index
    label_path_list = label_path
    image_paths_list = image_paths

    while True:
        
        images = []
        #drivable_area = np.array([])#np.ndarray(shape=(IMG_HEIGHT, IMG_WIDTH, NUM_SEG))
        maskes = []
        data_size = len(index_list)
        
        for i in range(batch_size):
            
            #image_id = images_ids.sample()
            
            index += 1
            if index >= data_size:
                index = 0
             
            #index = random.randint(0, data_size)
            img_url = image_paths_list[index_list[index]]
            label_url = label_path_list[index_list[index]]
            
            img = cv2.imread(img_url)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            mask = cv2.imread(label_url)
            mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
            
            img = img_process(img)
            mask = img_process(mask)

            mask = labels_to_maskes_reduce(mask, color_labels, NUM_SEG)
            
            images.append(img)
            maskes.append(mask) #.tolist()
            #drivable_area = np.append(drivable_area, rb_img, axis=0)

        yield (np.asarray(images), np.asarray(maskes)) # drivable_area

# %%
color_label_val = '../data/mapillary-vistas-dataset_public_v1.1/validation/labels/'

image_val = '../data/mapillary-vistas-dataset_public_v1.1/validation/images/'



classes_cc = { #cc = carla cityScape
    0: [0, 0, 0],        # None
    1: [70, 70, 70],     # Buildings
    2: [190, 153, 153],  # Fences
    3: [72, 0, 90],      # Other
    4: [220, 20, 60],    # Pedestrians
    5: [153, 153, 153],  # Poles
    6: [157, 234, 50],   # RoadLines
    7: [128, 64, 128],   # Roads
    8: [244, 35, 232],   # Sidewalks
    9: [107, 142, 35],   # Vegetation
    10: [0, 0, 255],     # Vehicles
    11: [102, 102, 156], # Walls
    12: [220, 220, 0]    # TrafficSigns
}

#Create dictonary for id to new id, add color for each id later. 
color_id_map = {
       0: [3], 
       1: [3], 
       2: [8],
       3: [2],
       4: [2],
       5: [3],
       6: [11],
       7: [8], 
       8: [7], 
       9: [8],
       10: [7], 
       11: [8], 
       12: [0], 
       13: [7],
       14: [7], 
       15: [8],
       16: [0], 
       17: [1],
       18: [0], 
       19: [4],
       20: [4],
       21: [10],
       22: [10],
       23: [6],
       24: [6],
       25: [0],
       26: [0],
       27: [0], 
       28: [0], 
       29: [0], 
       30: [9],
       31: [0], 
       32: [3],
       33: [3],
       34: [3],
       35: [3],
       36: [3],
       37: [3],
       38: [3],
       39: [3],
       40: [3],
       41: [7],
       42: [3],
       43: [7],
       44: [5],
       45: [5],
       46: [12],
       47: [5],
       48: [12],
       49: [12],
       50: [12],
       51: [3],
       52: [3],
       53: [3],
       54: [10],
       55: [10],
       56: [10],
       57: [10],
       58: [0], 
       59: [10],
       60: [10],
       61: [10],
       62: [10],
       63: [0],
       64: [0],
       65: [0],        
    }

# read in config file
with open('../data/mapillary-vistas-dataset_public_v1.1/config.json') as config_file:
    config = json.load(config_file)
# in this example we are only interested in the labels
labels = config['labels']

# print labels
print("There are {} labels in the config file".format(len(labels)))
for label_id, label in enumerate(labels):
    color_id_map[label_id].append(label["color"])
    #print("{:>30} ({:2d}): {:<40} has instances: {}".format(label["readable"], label_id, label["name"], label["instances"]))
        

IMG_HEIGHT = 480 #640x480, 320x240, 160x120
IMG_WIDTH = 640
NUM_SEG = 13

color_label_val_list = get_img_name(color_label_val)
img_val_list = get_img_name(image_val)
print(len(color_label_val_list))
print(len(img_val_list))
#_drivable_id.png
#_drivable_color.png

with open('model_info.json') as a:
    model_info = json.load(a)
    
for key, value in model_info.items():
    model_info[key]['round'] = 0
    model_info[key]['score'] = 0
    model_info[key]['used_index'] = []
    print(f'Key: {key}, value: {value}')
    print()
    
print('Keys')

#makes a copy for ubc algorithem wont get disurbed by old values
model_info_ubc1 = copy.deepcopy(model_info)
# Out:
# There are 66 labels in the config file
# 2000
# 2000
# Key: u-net_1585114900, value: {'created': 1585114900, 'training_time': 0, 'data_amount': 140, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'elu', 'dropout': 0.17, 'optimizer': 'Adam', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585115750, value: {'created': 1585115750, 'training_time': 0, 'data_amount': 144, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'sigmoid', 'dropout': 0.13, 'optimizer': 'Adam', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585116680, value: {'created': 1585116680, 'training_time': 0, 'data_amount': 117, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'elu', 'dropout': 0.48, 'optimizer': 'Adam', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585118770, value: {'created': 1585118770, 'training_time': 0, 'data_amount': 133, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'relu', 'dropout': 0.45, 'optimizer': 'Adam', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585123137, value: {'created': 1585123137, 'training_time': 0, 'data_amount': 139, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'elu', 'dropout': 0.18, 'optimizer': 'Adam', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585126633, value: {'created': 1585126633, 'training_time': 0, 'data_amount': 145, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'relu', 'dropout': 0.14, 'optimizer': 'Adam', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585130481, value: {'created': 1585130481, 'training_time': 0, 'data_amount': 149, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'hard_sigmoid', 'dropout': 0.42, 'optimizer': 'Adam', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585133766, value: {'created': 1585133766, 'training_time': 0, 'data_amount': 137, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'relu', 'dropout': 0.44, 'optimizer': 'Adam', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585136637, value: {'created': 1585136637, 'training_time': 0, 'data_amount': 104, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'tanh', 'dropout': 0.23, 'optimizer': 'SGD', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585145765, value: {'created': 1585145765, 'training_time': 0, 'data_amount': 117, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'elu', 'dropout': 0.28, 'optimizer': 'Adam', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585155175, value: {'created': 1585155175, 'training_time': 0, 'data_amount': 108, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'sigmoid', 'dropout': 0.26, 'optimizer': 'SGD', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585164469, value: {'created': 1585164469, 'training_time': 0, 'data_amount': 111, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'relu', 'dropout': 0.23, 'optimizer': 'SGD', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585201143, value: {'created': 1585201143, 'training_time': 0, 'data_amount': 102, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'elu', 'dropout': 0.21, 'optimizer': 'Adam', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_1585208398, value: {'created': 1585208398, 'training_time': 0, 'data_amount': 102, 'architecture': 'u-net', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'relu', 'dropout': 0
 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'relu', 'dropout': 0.41, 'optimizer': 'SGD', 'out_activation_func': 'softmax', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_small_1585954935, value: {'created': 1585954935, 'training_time': 2611, 'data_amount': 100, 'architecture': 'u-net_small', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'relu', 'dropout': 0.33, 'optimizer': 'Adam', 'out_activation_func': 'softmax', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_small_1585957546, value: {'created': 1585957546, 'training_time': 2221, 'data_amount': 37, 'architecture': 'u-net_small', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'relu', 'dropout': 0.41, 'optimizer': 'Adam', 'out_activation_func': 'sigmoid', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_small_1585959769, value: {'created': 1585959769, 'training_time': 4965, 'data_amount': 69, 'architecture': 'u-net_small', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'relu', 'dropout': 0.36, 'optimizer': 'Adam', 'out_activation_func': 'softmax', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Key: u-net_less_nodes_1585948346, value: {'created': 1585948346, 'training_time': 20707, 'data_amount': 186, 'architecture': 'u-net_less_nodes', 'dataset': 'map_vista', 'notes': 'no modification', 'activation_func': 'relu', 'dropout': 0.44, 'optimizer': 'SGD', 'out_activation_func': 'sigmoid', 'loss': 'binary_crossentropy', 'round': 0, 'score': 0, 'used_index': []}
#
# Keys

# %%
'''
y: prediction target (solution)
y_hat: prediction
returns: predictions in percentage
'''
def evaluate_prediction(y, y_hat):
    
    y_hat = (y_hat==y_hat.max(axis=2, keepdims=1)).astype(np.uint8)
    num_correct = y_hat * y
    width, height, _ = num_correct.shape
    max_score = width * height
    score = num_correct.sum()
    return score/max_score

# %%
imges, labels = next(batch_generator(img_val_list, color_label_val_list, color_id_map, [30], 1))
model = load_model(f'seg_models/u-net_1585114900.h5')

img_predicted = model.predict(imges)[0]
target = maskes_to_labels(labels[0]).astype(np.uint8)


print(img_predicted.shape)

y_train_label = maskes_to_labels(img_predicted).astype(np.uint8)
compare_img(imges[0], target, 'Image', 'CityScape labels')
compare_img(imges[0], y_train_label, 'Image', 'CityScape labels')
# Out:
# (480, 640, 13)

# %%
evaluate_prediction(y=labels[0], y_hat=img_predicted)
# Out:
# 0.620625

# %%
epsilon = 0.3
key_list = list(model_info.keys())
num_models = len(list(model_info.keys()))
index_list = range(0, len(img_val_list))
num_trials = len(index_list)
gen = batch_generator(img_val_list, color_label_val_list, color_id_map, index_list, 1)
scores = []
means = []
score_counter = []

#calculate old score with new
def calculate_score(rounds, score, old_score):
    return old_score * ((rounds-1)/rounds) + score *(1/rounds)


#output: score of model, mean and std
def try_model(key, imgs, labels, model_info, round_nr, lower_bound=True):
    old_score = model_info[key]['score']
    model_info[key]['round'] += 1
    rounds = model_info[key]['round']
    
    model = load_model(f'seg_models/{key}.h5')
    y_hat, mean, std = predictions_and_uncetrenty(model, 5, imgs)
    
    #make mean and std single values
    mean = mean.mean()
    std = std.mean()
    
    #print(y_hat.shape)
    score = evaluate_prediction(labels[0], y_hat)
    
    #change from only using mean to lover bound of derivation
    if lower_bound:
        mean_score = calculate_score(rounds, mean - std, old_score)
    else: 
        mean_score = calculate_score(rounds, mean, old_score)
    
    model_info[key]['score'] = mean_score
    model_info[key]['used_index'].append(round_nr)
    
   
    return score, mean, std

# %% [markdown]
# ## Multiarmed Bandit epilon gredy

# %%
# run bandit thought validation
for i in range(len(index_list)):
    
    #print(f'round: {i} of {len(index_list)}')
    imgs, labels = next(gen)
    if random.random() > epsilon:
        
        best_model_key = None
        best_score = -np.inf
        
        for key, value in model_info.items():
            if value['score'] > best_score:
                best_score = value['score']
                best_model_key = key
            
        new_score, mean, std = try_model(best_model_key, imgs, labels, model_info, i)
    else:
        #explore
        model_key = random.choice(key_list)
        new_score, mean, std = try_model(model_key, imgs, labels, model_info, i)
    
    #print(f'mean: {mean}, std: {std}')
    

    K.clear_session()
    scores.append(new_score)
    score_counter.append(new_score)
    means.append(mean)
    #epsilon *= gamma
    
    if i % 10 == 0:
        print(f'round: {i} of {len(index_list)}, score: {sum(score_counter)}')
        score_counter = []

# %%
#Reduce the list so graph get more general and easyer to read
def generalize_list(scores, batch_size):
    score_batch = []
    score_reduced = []
    x_akses = []
    for i in range(len(scores)):
        if i % batch_size == 0 and i != 0:
            score_reduced.append(sum(score_batch)/batch_size)
            score_batch = []
            x_akses.append(i)
        score_batch.append(scores[i])
    return score_reduced, x_akses

def score_graph(scores, means, model_info, batch_size):
    plt.figure(figsize=(16, 10))
    score_reduced = []


    model_score_avg = 0
    for key, value in model_info.items():
        model_score_avg += value['score']
    model_score_avg = model_score_avg / num_models


    # x_akses is the same in both instances
    score_reduced, x_akses = generalize_list(scores, batch_size)
    mean_reduced, _ = generalize_list(means, batch_size)
    
    print(f' Avg score pr model: {model_score_avg}')
    avg = np.array([model_score_avg for i in range(num_trials)])
    avg_explore = np.array([0.519 for i in range(num_trials)]) # 0.5186551321699284
    #plt.bar(, y_akses_list)
    plt.ylim(0,1)
    plt.xlabel('time', fontsize=20)
    plt.ylabel('Percentage right', fontsize=20)
    #plt.tick_params(axis='both', which='major', labelsize=18)

    plt.plot(avg, 'r--', label='Average Lower Bound')
    plt.plot(avg_explore, 'm--', label='Average score')
    plt.plot(x_akses, mean_reduced,'g' ,linewidth=3, label='Mean')
    plt.plot(x_akses, score_reduced,'b' ,linewidth=3, label='Score')
    plt.legend(loc='best', fontsize=15)
    plt.show()

score_graph(scores, means, model_info, batch_size=10)
# Out:
#  Avg score pr model: 0.0

# %%
for key, value in model_info.items():
    print(f'Key: {key}, score: {value["score"]}, rounds: {value["round"]}, time used: {value["used_index"]}')
    print()
# Out:
# Key: u-net_1585114900, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585115750, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585116680, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585118770, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585123137, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585126633, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585130481, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585133766, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585136637, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585145765, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585155175, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585164469, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585201143, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585208398, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585213881, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585227049, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585231644, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585234985, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585235812, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585236356, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585236911, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585239945, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585240214, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585241644, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585248396, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585248873, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585251387, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585296187, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585299468, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585299933, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585300789, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585304056, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585309248, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585311625, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585312689, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585314485, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585316829, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585317558, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585576696, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585577911, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585584942, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585586612, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585598383, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585621636, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585635122, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585641269, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585643717, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585642440, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585641098, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585650324, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585651913, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585652501, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585648615, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585655144, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585654109, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585659334, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585666095, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585662030, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585665140, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585665068, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585680690, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585672317, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585682751, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585687310, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585695697, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585684701, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585698681, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585696973, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585699061, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585706218, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585708279, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585700947, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585700678, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585715384, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585710094, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585720963, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585732393, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585732394, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585735313, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585734509, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585738780, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585741052, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585742960, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585747955, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585753973, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585753120, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585757605, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585761022, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585755442, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585764536, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585762918, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585768479, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585770050, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585772116, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585774150, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585808554, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585809842, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585824876, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585824864, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585827102, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585820062, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585830286, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585809511, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585827569, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585831163, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585823364, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585835063, score: 0, rounds: 0, time used: []
#
# Key: u-net_1585837994, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585840935, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585839319, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585849555, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585828700, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585851158, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585851364, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585855910, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585855909, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585858763, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585860919, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585851380, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585864108, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585860057, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585891158, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585895332, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585895333, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585905033, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585906080, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585914839, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585930822, score: 0, rounds: 0, time used: []
#
# Key: u-net_less_nodes_1585931232, score: 0, rounds: 0, time used: []
#
# Key: u-net_less_nodes_1585931366, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585946268, score: 0, rounds: 0, time used: []
#
# Key: u-net_less_nodes_1585950569, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585954935, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585957546, score: 0, rounds: 0, time used: []
#
# Key: u-net_small_1585959769, score: 0, rounds: 0, time used: []
#
# Key: u-net_less_nodes_1585948346, score: 0, rounds: 0, time used: []

# %%
def plot_model_used(model_info, num_models, num_trials, batch_size):
    model_used = np.zeros((num_models, num_trials), dtype=np.uint8)

    #smooth = (len(index_list)+batch_size)//batch_size
    #print(smooth)

    counter = 0
    for key, value in model_info.items():
        #model_used[counter]
        for index in value['used_index']:
            model_used[counter][index] = 1

        counter += 1 

    model_used_smoothe = [] #np.zeros((len(key_list), smooth), dtype=np.uint8)
    counter = 0
    for used in model_used:
        periodic = []
        model_used_smoothe.append([])
        for i in range(len(used)):
            if i % batch_size == 0 and i != 0:
                model_used_smoothe[counter].append(sum(periodic))
                periodic = []
            periodic.append(used[i])
        counter += 1


    plt.figure(figsize=(16, 10))
    plt.tick_params(axis='both', which='major', labelsize=15)

    for used_per in model_used_smoothe:
        #print(used_per)
        plt.plot(used_per)
    #print(model_used_smoothe[5])
    #plt.plot(model_used_smoothe[5])
    plt.show()
plot_model_used(model_info, num_models, num_trials, batch_size=10)

# %%
def scatter_model_used(model_info):
    counter = 0
    used_list = np.zeros(num_trials)

    for key, value in model_info.items():

        for used in value['used_index']:
            used_list[used] = counter

        counter += 1
    counter_list = range(num_trials)
    plt.figure(figsize=(16, 10))
    plt.tick_params(axis='both', which='major', labelsize=15)
    plt.scatter(counter_list, used_list)
    plt.show()
scatter_model_used(model_info)

# %%
print('Average ressults') #0.3, 0.2
print(f'Score: {np.array(scores).mean()}') #0.6452791124131944, #0.6169490690104167
print(f'Mean: {np.array(means).mean()}') # 0.6408893465995789, #0.6559882760047913
# Out:
# Average ressults
# Score: nan
# Mean: nan
# /home/torresrl/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: Mean of empty slice.
#
# /home/torresrl/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/torresrl/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: Mean of empty slice.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## UCB1

# %%
gen = batch_generator(img_val_list, color_label_val_list, color_id_map, index_list, 1)

scores_ucb1 = []
means_ucb1 = []
score_counter_ucb1 = []


def ucb1_score(rounds, model_info, c):
    model_round = model_info['round']
    
    if model_round == 0:
        return np.inf
    #print(f'rounds: {model_info["round"]} ,score: {model_info["score"]} time used: {model_info["used_index"]}')
    explotation = model_info['score']
    explortion = math.sqrt(math.log(rounds)/model_round)
    
    return explotation + c*explortion


# run bandit thought validation
for i in range(len(index_list)):
    
    #print(f'round: {i} of {len(index_list)}')
    imgs, labels = next(gen)

        
    best_model_key = None
    best_score = -np.inf
    printe_score = True
    
    for key, value in model_info_ubc1.items():
        score = ucb1_score(rounds=i, model_info=value, c=0.05) 
        #save some init time
        if score == np.inf:
            if i > num_models:
                print('FAAAAIL')
            best_model_key = key
            break
            
        if printe_score:
            printe_score = False
        
        if score > best_score:
            best_score = score
            best_model_key = key
            
    
    new_score, mean, std = try_model(best_model_key, imgs, labels, model_info_ubc1, i)

    
    #print(f'mean: {mean}, std: {std}')
    

    K.clear_session()
    scores_ucb1.append(new_score)
    score_counter_ucb1.append(new_score)
    means_ucb1.append(mean)
    #epsilon *= gamma
    
    if i % 10 == 0:
        printe_score = True
        print(f'round: {i} of {len(index_list)}, score: {sum(score_counter_ucb1)}')
        score_counter_ucb1 = []
# Out:
# round: 0 of 2000, score: 0.5676627604166666
# round: 10 of 2000, score: 5.743011067708333
# round: 20 of 2000, score: 6.038977864583334
# round: 30 of 2000, score: 3.6160156249999993
# round: 40 of 2000, score: 4.503434244791666
# round: 50 of 2000, score: 5.849287109375
# round: 60 of 2000, score: 5.658990885416666
# round: 70 of 2000, score: 5.441181640625
# round: 80 of 2000, score: 5.629957682291667
# round: 90 of 2000, score: 4.915494791666666
# round: 100 of 2000, score: 4.264638671875
# round: 110 of 2000, score: 5.001949869791668
# round: 120 of 2000, score: 5.9240625
# round: 130 of 2000, score: 4.521575520833333
# round: 140 of 2000, score: 5.359541015625
# round: 150 of 2000, score: 7.0123079427083335
# round: 160 of 2000, score: 6.353590494791668
# round: 170 of 2000, score: 5.463121744791667
# round: 180 of 2000, score: 5.926933593750001
# round: 190 of 2000, score: 6.152923177083332
# round: 200 of 2000, score: 5.677138671875
# round: 210 of 2000, score: 5.9613248697916665
# round: 220 of 2000, score: 6.133850911458333
# round: 230 of 2000, score: 6.630126953125
# round: 240 of 2000, score: 5.8332714843749995
# round: 250 of 2000, score: 5.508330078125
# round: 260 of 2000, score: 4.821399739583333
# round: 270 of 2000, score: 5.374401041666666
# round: 280 of 2000, score: 6.883955078125
# round: 290 of 2000, score: 5.182360026041666
# round: 300 of 2000, score: 5.235970052083333
# round: 310 of 2000, score: 5.582578125
# round: 320 of 2000, score: 6.4649869791666665
# round: 330 of 2000, score: 6.552415364583333
# round: 340 of 2000, score: 4.679547526041667
# round: 350 of 2000, score: 6.047477213541666
# round: 360 of 2000, score: 5.18041015625
# round: 370 of 2000, score: 6.979085286458333
# round: 380 of 2000, score: 6.601881510416667
# round: 390 of 2000, score: 6.316002604166667
# round: 400 of 2000, score: 6.142086588541668
# round: 410 of 2000, score: 5.098053385416666
# round: 420 of 2000, score: 7.320797526041666
# round: 430 of 2000, score: 5.529677734375
# round: 440 of 2000, score: 5.43998046875
# round: 450 of 2000, score: 4.5339973958333335
# round: 460 of 2000, score: 5.563359375
# round: 470 of 2000, score: 5.820387369791667
# round: 480 of 2000, score: 5.966357421874999
# round: 490 of 2000, score: 7.229423828125001
# round: 500 of 2000, score: 7.469645182291667
# round: 510 of 2000, score: 7.2442447916666675
# round: 1890 of 2000, score: 4.511276041666667
# round: 1900 of 2000, score: 6.810667317708333
# round: 1910 of 2000, score: 7.4607552083333335
# round: 1920 of 2000, score: 6.588401692708333
# round: 1930 of 2000, score: 6.877089843750001
# round: 1940 of 2000, score: 7.525078125000001
# round: 1950 of 2000, score: 8.073694661458333
# round: 1960 of 2000, score: 6.994059244791667
# round: 1970 of 2000, score: 7.465250651041666
# round: 1980 of 2000, score: 7.617623697916666
# round: 1990 of 2000, score: 7.016770833333334

# %%
score_graph(scores_ucb1, means_ucb1, model_info_ubc1, batch_size=10)
# Out:
#  Avg score pr model: 0.2356226303998163

# %%
for key, value in model_info_ubc1.items():
    print(f'Key: {key}, rounds: {value["round"]} ,score: {value["score"]} time used: {value["used_index"]}')
    print()
# Out:
# Key: u-net_1585114900, rounds: 13 ,score: 0.30287760416666665 time used: [0, 259, 260, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482]
#
# Key: u-net_1585115750, rounds: 5 ,score: 0.221728515625 time used: [1, 204, 340, 341, 342]
#
# Key: u-net_1585116680, rounds: 4 ,score: 0.27875325520833333 time used: [2, 442, 1057, 1058]
#
# Key: u-net_1585118770, rounds: 24 ,score: 0.3185221354166667 time used: [3, 189, 190, 191, 192, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692]
#
# Key: u-net_1585123137, rounds: 2 ,score: 0.26434895833333333 time used: [4, 408]
#
# Key: u-net_1585126633, rounds: 92 ,score: 0.3134375 time used: [5, 146, 281, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 674, 675, 676, 677, 678, 679, 680, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472]
#
# Key: u-net_1585130481, rounds: 3 ,score: 0.27025390625 time used: [6, 179, 521]
#
# Key: u-net_1585133766, rounds: 28 ,score: 0.298037109375 time used: [7, 297, 912, 913, 914, 915, 1255, 1256, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620]
#
# Key: u-net_1585136637, rounds: 3 ,score: 0.024228515625 time used: [8, 334, 1221]
#
# Key: u-net_1585145765, rounds: 3 ,score: 0.27375651041666665 time used: [9, 644, 645]
#
# Key: u-net_1585155175, rounds: 4 ,score: 0.03170572916666667 time used: [10, 161, 628, 629]
#
# Key: u-net_1585164469, rounds: 5 ,score: 0.26280598958333334 time used: [11, 282, 518, 519, 1725]
#
# Key: u-net_1585201143, rounds: 2 ,score: 0.21064453125 time used: [12, 291]
#
# Key: u-net_1585208398, rounds: 9 ,score: 0.219130859375 time used: [13, 234, 475, 476, 530, 1858, 1859, 1860, 1861]
#
# Key: u-net_1585213881, rounds: 5 ,score: 0.269970703125 time used: [14, 213, 464, 579, 580]
#
# Key: u-net_1585227049, rounds: 6 ,score: 0.19146809895833333 time used: [15, 384, 385, 386, 668, 669]
#
# Key: u-net_1585231644, rounds: 104 ,score: 0.31111328125 time used: [16, 154, 155, 449, 450, 451, 452, 520, 524, 525, 526, 527, 528, 529, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363]
#
# Key: u-net_1585234985, rounds: 3 ,score: 0.15709309895833334 time used: [17, 214, 215]
#
# Key: u-net_1585235812, rounds: 15 ,score: 0.13908528645833335 time used: [18, 345, 601, 602, 603, 604, 605, 606, 607, 608, 1498, 1499, 1500, 1501, 1502]
#
# Key: u-net_1585236356, rounds: 9 ,score: 0.30392578125 time used: [19, 156, 157, 219, 220, 221, 222, 223, 1220]
#
# Key: u-net_1585236911, rounds: 13 ,score: 0.23341471354166668 time used: [20, 158, 159, 197, 198, 293, 294, 295, 296, 391, 401, 568, 569]
#
# Key: u-net_1585239945, rounds: 4 ,score: 0.30631184895833335 time used: [21, 235, 236, 237]
#
# Key: u-net_1585240214, rounds: 18 ,score: 0.7788704427083334 time used: [22, 148, 149, 460, 533, 534, 535, 536, 537, 538, 539, 540, 541, 1995, 1996, 1997, 1998, 1999]
#
# Key: u-net_1585241644, rounds: 1 ,score: 0.017109375 time used: [23]
#
# Key: u-net_1585248396, rounds: 1 ,score: 0.13232096354166667 time used: [24]
#
# Key: u-net_1585248873, rounds: 7 ,score: 0.140390625 time used: [25, 823, 1494, 1495, 1598, 1599, 1600]
#
# Key: u-net_1585251387, rounds: 1 ,score: 0.22262369791666667 time used: [26]
#
# Key: u-net_small_1585296187, rounds: 10 ,score: 0.22859700520833334 time used: [27, 357, 358, 359, 1537, 1538, 1539, 1540, 1541, 1542]
#
# Key: u-net_small_1585299468, rounds: 1 ,score: 0.086279296875 time used: [28]
#
# Key: u-net_small_1585299933, rounds: 4 ,score: 0.2585091145833333 time used: [29, 231, 232, 233]
#
# Key: u-net_small_1585300789, rounds: 14 ,score: 0.2856217447916667 time used: [30, 687, 688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 1503, 1504]
#
# Key: u-net_small_1585304056, rounds: 5 ,score: 0.1510546875 time used: [31, 207, 574, 795, 877]
#
# Key: u-net_small_1585309248, rounds: 6 ,score: 0.22780598958333334 time used: [32, 426, 427, 428, 429, 430]
#
# Key: u-net_small_1585311625, rounds: 6 ,score: 0.065068359375 time used: [33, 360, 361, 362, 437, 438]
#
# Key: u-net_small_1585312689, rounds: 13 ,score: 0.29440104166666664 time used: [34, 169, 283, 439, 440, 441, 698, 699, 700, 948, 949, 950, 951]
#
# Key: u-net_small_1585314485, rounds: 16 ,score: 0.2541373697916667 time used: [35, 199, 555, 556, 557, 558, 559, 560, 561, 661, 662, 663, 664, 665, 787, 788]
#
# Key: u-net_small_1585316829, rounds: 3 ,score: 0.17295247395833332 time used: [36, 242, 292]
#
# Key: u-net_small_1585317558, rounds: 1 ,score: 0.09849283854166667 time used: [37]
#
# Key: u-net_small_1585576696, rounds: 22 ,score: 0.2762141927083333 time used: [38, 387, 388, 389, 390, 624, 625, 626, 627, 952, 953, 954, 955, 956, 957, 958, 959, 960, 961, 1275, 1276, 1277]
#
# Key: u-net_small_1585577911, rounds: 1 ,score: 0.19974283854166666 time used: [39]
#
# Key: u-net_small_1585584942, rounds: 3 ,score: 0.206669921875 time used: [40, 1214, 1215]
#
# Key: u-net_1585586612, rounds: 10 ,score: 0.3257063802083333 time used: [41, 268, 269, 270, 271, 272, 273, 303, 304, 310]
#
# Key: u-net_1585598383, rounds: 7 ,score: 0.233427734375 time used: [42, 247, 248, 249, 658, 659, 660]
#
# Key: u-net_1585621636, rounds: 269 ,score: 0.289150390625 time used: [43, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 542, 543, 544, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994]
#
# Key: u-net_1585635122, rounds: 43 ,score: 0.25278645833333335 time used: [44, 180, 181, 267, 522, 523, 570, 681, 682, 683, 684, 685, 686, 926, 927, 928, 929, 930, 931, 932, 933, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724]
#
# Key: u-net_1585641269, rounds: 10 ,score: 0.2949576822916667 time used: [45, 166, 307, 308, 1647, 1648, 1649, 1650, 1651, 1652]
#
# Key: u-net_1585643717, rounds: 14 ,score: 0.22803059895833333 time used: [46, 239, 240, 241, 471, 472, 473, 474, 1569, 1570, 1571, 1572, 1573, 1574]
#
# Key: u-net_1585642440, rounds: 47 ,score: 0.2528938802083333 time used: [47, 287, 288, 289, 333, 344, 434, 435, 436, 666, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124]
#
# Key: u-net_1585641098, rounds: 5 ,score: 0.14055989583333334 time used: [48, 202, 203, 919, 920]
#
# Key: u-net_1585650324, rounds: 2 ,score: 0.24196940104166667 time used: [49, 258]
#
# Key: u-net_1585651913, rounds: 4 ,score: 0.27640625 time used: [50, 212, 617, 618]
#
# Key: u-net_1585652501, rounds: 4 ,score: 0.23674153645833335 time used: [51, 250, 251, 796]
#
# Key: u-net_1585648615, rounds: 2 ,score: 0.22013020833333333 time used: [52, 921]
#
# Key: u-net_1585655144, rounds: 16 ,score: 0.3101497395833333 time used: [53, 184, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376]
#
# Key: u-net_1585654109, rounds: 39 ,score: 0.24306966145833334 time used: [54, 136, 165, 275, 276, 277, 278, 279, 280, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186]
#
# Key: u-net_1585659334, rounds: 41 ,score: 0.3338704427083333 time used: [55, 160, 186, 187, 188, 825, 826, 827, 828, 829, 830, 831, 832, 833, 834, 835, 836, 837, 871, 872, 873, 874, 875, 876, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639]
#
# Key: u-net_1585666095, rounds: 6 ,score: 0.30885416666666665 time used: [56, 209, 210, 211, 252, 1243]
#
# Key: u-net_1585662030, rounds: 13 ,score: 0.22359049479166668 time used: [57, 178, 196, 962, 963, 964, 965, 966, 967, 968, 969, 1496, 1497]
#
# Key: u-net_1585665140, rounds: 26 ,score: 0.30231119791666666 time used: [58, 609, 610, 707, 708, 709, 710, 711, 712, 713, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991]
#
# Key: u-net_1585665068, rounds: 29 ,score: 0.12455729166666667 time used: [59, 286, 646, 1187, 1188, 1189, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567]
#
# Key: u-net_1585680690, rounds: 7 ,score: 0.32234049479166665 time used: [60, 970, 971, 972, 973, 974, 975]
#
# Key: u-net_1585672317, rounds: 5 ,score: 0.157177734375 time used: [61, 151, 554, 879, 880]
#
# Key: u-net_1585682751, rounds: 3 ,score: 0.062415364583333334 time used: [62, 1300, 1301]
#
# Key: u-net_1585687310, rounds: 10 ,score: 0.235400390625 time used: [63, 791, 792, 793, 794, 1154, 1155, 1156, 1621, 1622]
#
# Key: u-net_1585695697, rounds: 32 ,score: 0.25679361979166665 time used: [64, 173, 174, 863, 864, 865, 866, 867, 868, 869, 870, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1190, 1191, 1192, 1193]
#
# Key: u-net_1585684701, rounds: 10 ,score: 0.23358072916666667 time used: [65, 403, 789, 790, 1880, 1881, 1882, 1883, 1884, 1885]
#
# Key: u-net_1585698681, rounds: 6 ,score: 0.22796223958333334 time used: [66, 1433, 1434, 1435, 1543, 1544]
#
# Key: u-net_1585696973, rounds: 15 ,score: 0.12001627604166666 time used: [67, 163, 261, 1037, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254]
#
# Key: u-net_1585699061, rounds: 48 ,score: 0.3096484375 time used: [68, 253, 290, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422]
#
# Key: u-net_1585706218, rounds: 2 ,score: 0.23849283854166667 time used: [69, 354]
#
# Key: u-net_1585708279, rounds: 8 ,score: 0.28380208333333334 time used: [70, 141, 443, 444, 1302, 1303, 1304, 1305]
#
# Key: u-net_1585700947, rounds: 7 ,score: 0.24912109375 time used: [71, 185, 201, 216, 217, 218, 335]
#
# Key: u-net_1585700678, rounds: 1 ,score: 0.13472005208333335 time used: [72]
#
# Key: u-net_1585715384, rounds: 38 ,score: 0.322744140625 time used: [73, 255, 256, 309, 562, 563, 564, 565, 850, 851, 852, 853, 854, 855, 856, 857, 858, 859, 860, 861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879]
#
# Key: u-net_1585710094, rounds: 3 ,score: 0.25851236979166664 time used: [74, 285, 547]
#
# Key: u-net_1585720963, rounds: 9 ,score: 0.10717122395833334 time used: [75, 274, 394, 395, 396, 397, 398, 399, 400]
#
# Key: u-net_1585732393, rounds: 2 ,score: 0.2741341145833333 time used: [76, 1217]
#
# Key: u-net_1585732394, rounds: 10 ,score: 0.28561848958333336 time used: [77, 138, 167, 208, 322, 323, 324, 325, 326, 327]
#
# Key: u-net_1585735313, rounds: 12 ,score: 0.20525390625 time used: [78, 170, 262, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067]
#
# Key: u-net_1585734509, rounds: 3 ,score: 0.19788736979166666 time used: [79, 140, 311]
#
# Key: u-net_1585738780, rounds: 5 ,score: 0.2552766927083333 time used: [80, 312, 313, 314, 315]
#
# Key: u-net_1585741052, rounds: 7 ,score: 0.31318033854166666 time used: [81, 175, 453, 454, 455, 904, 1153]
#
# Key: u-net_1585742960, rounds: 2 ,score: 0.252216796875 time used: [82, 1568]
#
# Key: u-net_1585747955, rounds: 5 ,score: 0.31155598958333336 time used: [83, 150, 152, 238, 402]
#
# Key: u-net_1585753973, rounds: 2 ,score: 0.09107096354166666 time used: [84, 1886]
#
# Key: u-net_1585753120, rounds: 5 ,score: 0.2727994791666667 time used: [85, 225, 431, 432, 433]
#
# Key: u-net_1585757605, rounds: 2 ,score: 0.07076497395833334 time used: [86, 339]
#
# Key: u-net_1585761022, rounds: 2 ,score: 0.10763671875 time used: [87, 266]
#
# Key: u-net_1585755442, rounds: 2 ,score: 0.13225911458333334 time used: [88, 1008]
#
# Key: u-net_1585764536, rounds: 9 ,score: 0.30345703125 time used: [89, 164, 461, 462, 463, 550, 551, 552, 553]
#
# Key: u-net_1585762918, rounds: 12 ,score: 0.22263997395833332 time used: [90, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493]
#
# Key: u-net_1585768479, rounds: 7 ,score: 0.271396484375 time used: [91, 611, 612, 613, 614, 615, 616]
#
# Key: u-net_1585770050, rounds: 43 ,score: 0.34103190104166664 time used: [92, 670, 671, 672, 673, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1306, 1307, 1308]
#
# Key: u-net_1585772116, rounds: 1 ,score: 0.18747395833333333 time used: [93]
#
# Key: u-net_1585774150, rounds: 4 ,score: 0.28862630208333334 time used: [94, 183, 566, 567]
#
# Key: u-net_1585808554, rounds: 1 ,score: 0.12428059895833334 time used: [95]
#
# Key: u-net_1585809842, rounds: 97 ,score: 0.23215169270833333 time used: [96, 142, 147, 162, 305, 306, 722, 723, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 797, 798, 799, 800, 801, 802, 803, 804, 805, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822]
#
# Key: u-net_small_1585824876, rounds: 4 ,score: 0.27226888020833334 time used: [97, 200, 667, 1213]
#
# Key: u-net_small_1585824864, rounds: 16 ,score: 0.33326171875 time used: [98, 634, 635, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1216, 1241, 1242]
#
# Key: u-net_small_1585827102, rounds: 11 ,score: 0.27765299479166666 time used: [99, 392, 393, 898, 899, 900, 901, 902, 903, 1038, 1039]
#
# Key: u-net_1585820062, rounds: 3 ,score: 0.16138346354166666 time used: [100, 1218, 1219]
#
# Key: u-net_1585830286, rounds: 19 ,score: 0.28009440104166666 time used: [101, 714, 715, 716, 882, 883, 884, 885, 886, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896]
#
# Key: u-net_1585809511, rounds: 2 ,score: 0.26958984375 time used: [102, 139]
#
# Key: u-net_small_1585827569, rounds: 27 ,score: 0.2888411458333333 time used: [103, 224, 377, 378, 379, 380, 381, 382, 383, 622, 623, 636, 637, 638, 639, 640, 641, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432]
#
# Key: u-net_1585831163, rounds: 23 ,score: 0.33569986979166666 time used: [104, 575, 576, 577, 578, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274]
#
# Key: u-net_1585823364, rounds: 38 ,score: 0.30529622395833333 time used: [105, 717, 718, 719, 720, 721, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536]
#
# Key: u-net_small_1585835063, rounds: 25 ,score: 0.32310872395833334 time used: [106, 263, 264, 265, 328, 329, 330, 331, 332, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087]
#
# Key: u-net_1585837994, rounds: 12 ,score: 0.20169270833333333 time used: [107, 144, 145, 316, 317, 318, 319, 320, 321, 336, 337, 338]
#
# Key: u-net_small_1585840935, rounds: 3 ,score: 0.19787760416666667 time used: [108, 470, 992]
#
# Key: u-net_small_1585839319, rounds: 3 ,score: 0.11946614583333333 time used: [109, 642, 643]
#
# Key: u-net_small_1585849555, rounds: 13 ,score: 0.14642903645833333 time used: [110, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375]
#
# Key: u-net_small_1585828700, rounds: 9 ,score: 0.3036881510416667 time used: [111, 182, 245, 705, 706, 897, 916, 917, 918]
#
# Key: u-net_small_1585851158, rounds: 28 ,score: 0.30001627604166664 time used: [112, 243, 244, 299, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 905, 906, 907, 908, 909, 910, 911, 1003, 1004, 1005, 1006, 1007]
#
# Key: u-net_small_1585851364, rounds: 3 ,score: 0.272763671875 time used: [113, 355, 356]
#
# Key: u-net_small_1585855910, rounds: 27 ,score: 0.3024544270833333 time used: [114, 168, 630, 631, 632, 633, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673]
#
# Key: u-net_small_1585855909, rounds: 58 ,score: 0.298935546875 time used: [115, 177, 257, 409, 410, 411, 412, 647, 648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240]
#
# Key: u-net_small_1585858763, rounds: 4 ,score: 0.18626302083333332 time used: [116, 619, 620, 621]
#
# Key: u-net_small_1585860919, rounds: 10 ,score: 0.2870182291666667 time used: [117, 137, 445, 446, 447, 1642, 1643, 1644, 1645, 1646]
#
# Key: u-net_small_1585851380, rounds: 6 ,score: 0.177119140625 time used: [118, 176, 206, 254, 545, 546]
#
# Key: u-net_small_1585864108, rounds: 2 ,score: 0.2704622395833333 time used: [119, 881]
#
# Key: u-net_small_1585860057, rounds: 2 ,score: 0.25604166666666667 time used: [120, 246]
#
# Key: u-net_small_1585891158, rounds: 22 ,score: 0.313095703125 time used: [121, 171, 346, 347, 348, 349, 350, 351, 352, 353, 548, 549, 701, 702, 703, 704, 1310, 1311, 1312, 1313, 1314, 1315]
#
# Key: u-net_small_1585895332, rounds: 30 ,score: 0.33501953125 time used: [122, 193, 194, 195, 477, 478, 479, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597]
#
# Key: u-net_small_1585895333, rounds: 2 ,score: 0.24020182291666667 time used: [123, 862]
#
# Key: u-net_small_1585905033, rounds: 5 ,score: 0.28565104166666666 time used: [124, 1068, 1069, 1070, 1071]
#
# Key: u-net_small_1585906080, rounds: 4 ,score: 0.05060221354166667 time used: [125, 922, 1640, 1641]
#
# Key: u-net_small_1585914839, rounds: 3 ,score: 0.2686848958333333 time used: [126, 1376, 1377]
#
# Key: u-net_small_1585930822, rounds: 36 ,score: 0.230712890625 time used: [127, 226, 227, 228, 229, 230, 465, 466, 467, 468, 469, 878, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716]
#
# Key: u-net_less_nodes_1585931232, rounds: 6 ,score: 0.31000325520833333 time used: [128, 172, 284, 571, 572, 573]
#
# Key: u-net_less_nodes_1585931366, rounds: 1 ,score: 0.17166341145833333 time used: [129]
#
# Key: u-net_small_1585946268, rounds: 3 ,score: 0.085419921875 time used: [130, 298, 448]
#
# Key: u-net_less_nodes_1585950569, rounds: 3 ,score: 0.15171875 time used: [131, 531, 532]
#
# Key: u-net_small_1585954935, rounds: 1 ,score: 0.23796549479166668 time used: [132]
#
# Key: u-net_small_1585957546, rounds: 14 ,score: 0.28546223958333333 time used: [133, 205, 300, 301, 302, 404, 405, 406, 407, 456, 457, 458, 459, 1309]
#
# Key: u-net_small_1585959769, rounds: 6 ,score: 0.31619466145833336 time used: [134, 143, 153, 923, 924, 925]
#
# Key: u-net_less_nodes_1585948346, rounds: 3 ,score: 0.19560546875 time used: [135, 343, 824]

# %%
plot_model_used(model_info_ubc1, num_models, num_trials, batch_size=10)

# %%
scatter_model_used(model_info_ubc1)

# %%
print('Average ressults')
print(f'Score: {np.array(scores_ucb1).mean()}')
print(f'Mean: {np.array(means_ucb1).mean()}')
# Out:
# Average ressults
# Score: 0.6147572607421875
# Mean: 0.6160003542900085

# %% [markdown]
# Average ressults 0.005
# Score: 0.6762749348958333
# Mean: 0.6959035396575928
#
# Average ressults 0.01
# Score: 0.6346883984375001
# Mean: 0.6770832538604736
#
# Average ressults 0.05
# Score: 0.670639118923611
# Mean: 0.6933058500289917
