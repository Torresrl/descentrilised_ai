# %%
import glob
import cv2
import math 
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import json
import datetime
import matplotlib.image as mpimg
import random
import time


# %matplotlib inline
import pandas as pd
import numpy as np
np.random.bit_generator = np.random._bit_generator

from tensorflow.keras.preprocessing import image
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, Conv2D, Dropout, Flatten,MaxPooling2D, concatenate, UpSampling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.models import Model,load_model
#from keras_segmentation.models.model_utils import get_segmentation_mode
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
#from tensorflow.contrib import distributions

# from tensorflow.keras.utils import np_utils
from skimage.transform import resize
from datetime import datetime
from mpl_toolkits.mplot3d import Axes3D
from imgaug import augmenters as iaa
from imgaug.augmentables.segmaps import SegmentationMapsOnImage

# %%
color_label_val = '../data/mapillary-vistas-dataset_public_v1.1/validation/labels/'
color_label_train = '../data/mapillary-vistas-dataset_public_v1.1/training/labels/'

image_val = '../data/mapillary-vistas-dataset_public_v1.1/validation/images/'
image_train = '../data/mapillary-vistas-dataset_public_v1.1/training/images/'



IMG_HEIGHT = 480 #640x480, 320x240, 160x120
IMG_WIDTH = 640
NUM_SEG = 13
#_drivable_id.png
#_drivable_color.png

# %%
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.gpu_options.per_process_gpu_memory_fraction = 0.8
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device

# %%
from tensorflow.python.client import device_lib

tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#Create dictonary for id to new id, add color for each id later. 

color_id_map = {
       0: [3], 
       1: [3], 
       2: [8],
       3: [2],
       4: [2],
       5: [3],
       6: [11],
       7: [8], 
       8: [7], 
       9: [8],
       10: [7], 
       11: [8], 
       12: [0], 
       13: [7],
       14: [7], 
       15: [8],
       16: [0], 
       17: [1],
       18: [0], 
       19: [4],
       20: [4],
       21: [10],
       22: [10],
       23: [6],
       24: [6],
       25: [0],
       26: [0],
       27: [0], 
       28: [0], 
       29: [0], 
       30: [9],
       31: [0], 
       32: [3],
       33: [3],
       34: [3],
       35: [3],
       36: [3],
       37: [3],
       38: [3],
       39: [3],
       40: [3],
       41: [7],
       42: [3],
       43: [7],
       44: [5],
       45: [5],
       46: [12],
       47: [5],
       48: [12],
       49: [12],
       50: [12],
       51: [3],
       52: [3],
       53: [3],
       54: [10],
       55: [10],
       56: [10],
       57: [10],
       58: [0], 
       59: [10],
       60: [10],
       61: [10],
       62: [10],
       63: [0],
       64: [0],
       65: [0],        
    }

# %%
classes_cc = { #cc = carla cityScape
    0: [0, 0, 0],        # None
    1: [70, 70, 70],     # Buildings
    2: [190, 153, 153],  # Fences
    3: [72, 0, 90],      # Other
    4: [220, 20, 60],    # Pedestrians
    5: [153, 153, 153],  # Poles
    6: [157, 234, 50],   # RoadLines
    7: [128, 64, 128],   # Roads
    8: [244, 35, 232],   # Sidewalks
    9: [107, 142, 35],   # Vegetation
    10: [0, 0, 255],     # Vehicles
    11: [102, 102, 156], # Walls
    12: [220, 220, 0]    # TrafficSigns
}

# %%
def img_array_to_single_val(arr, color_codes):
    result = np.ndarray(shape=arr.shape[:2], dtype=int)
    result[:,:] = -1
    for idx, rgb in color_codes.items():
        result[(arr==rgb).all(2)] = idx
    return result

def id_map(img_label, color_id_map):
    num_objects = len(color_id_map.keys())
    
    height = img_label.shape[0]
    width = img_label.shape[1]
    
    channel = np.zeros((height, width), dtype=np.int8)
    
    
    for key, value in color_id_map.items():
        mask = (img_label == value[1]).all(-1)
        channel += value[0] * mask
    
    
    return channel
    


def random_augment(img, mask_rgb):
    #mask = id_map(img, classes_cc)
    mask = id_map(mask_rgb, color_id_map)


    seq = iaa.Sequential([
        iaa.Fliplr(0.5),
        #iaa.Multiply((0.95, 1.05)), den suger
        #iaa.Dropout([0.0, 0.2]),
        iaa.Add((-20, 20)), 
        #iaa.Superpixels(p_replace=0.3, n_segments=32),
        #iaa.Affine(scale=(1, 1.2),translate_percent=(-0.1, 0.1),rotate=(-10, 10),shear=(-2, 2))
        iaa.Affine(scale=(1, 1.3),shear=(-2, 2)) # behold denne 
        
    ])

    
    height, width, _ = img.shape
    segmap = SegmentationMapsOnImage(mask, shape=img.shape)
    
    img_aug, mask = seq(image=img, segmentation_maps=segmap)
    #mask = mask.draw(size=) #classes_cc
    colors = classes_cc.values()
    
    
    mask = mask.draw([height, width, NUM_SEG], colors=colors)[0] #, colors=[(0, 0, 0), (255, 0, 0), (0, 0, 255)]
    #c1, _, _ = cv2.split(mask[0])
    #c2, _, _ = cv2.split(mask[2])
    
    #rb_mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 2), dtype=np.uint8)
    #rb_mask[..., 0] = c1
    #rb_mask[..., 1] = c2
    
    return img_aug, mask

def apply_color_map(image_array, labels):
    color_array = np.zeros((image_array.shape[0], image_array.shape[1], 3), dtype=np.uint8)
    print(image_array.shape)
    print(color_array.shape)
    for label_id, label in enumerate(labels):
        # set all pixels with the current label to the color of the current label
        #print(label["color"])
        image_array[:,:,:] == label["color"]
        color_array[image_array == label_id] = label["color"]
        #print(color_array[image_array == label_id])

    return color_array

def get_img_name(path):
    names = glob.glob(f"{path}*")
    names.sort()
    return names

def img_process(img):
    img = cv2.resize(img, (IMG_WIDTH,IMG_HEIGHT)) #640x480, 320x240
    return img

def show_seg_on_img(img, mask, alpha=0.5):
    #img = img.astype(np.float64)*255
    #img = cv2.normalize(img, None, 0, 255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8UC3)
    #mask = mask.astype(np.float64)*255
    #mask = cv2.normalize(mask, None, 0, 255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8UC3)
    
    img_mask = cv2.addWeighted(mask, alpha, img, 0.5, 0)
    return img_mask 

def compare_img(img1, img2, title1 = 'Image 1', title2 = 'Image 2'):
    #img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    #img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
    
    fig = plt.figure(figsize=(16, 12))
    a = fig.add_subplot(1,2,1)
    imgplot = plt.imshow(img1)
    a.set_title(title1)

    a = fig.add_subplot(1, 2, 2)
    imgplot = plt.imshow(img2)
    a.set_title(title2)

# %%
    # read in config file
    with open('../data/mapillary-vistas-dataset_public_v1.1/config.json') as config_file:
        config = json.load(config_file)
    # in this example we are only interested in the labels
    labels = config['labels']

    # print labels
    print("There are {} labels in the config file".format(len(labels)))
    for label_id, label in enumerate(labels):
        color_id_map[label_id].append(label["color"])
        print("{:>30} ({:2d}): {:<40} has instances: {}".format(label["readable"], label_id, label["name"], label["instances"]))
# Out:
# There are 66 labels in the config file
#                           Bird ( 0): animal--bird                             has instances: True
#                  Ground Animal ( 1): animal--ground-animal                    has instances: True
#                           Curb ( 2): construction--barrier--curb              has instances: False
#                          Fence ( 3): construction--barrier--fence             has instances: False
#                     Guard Rail ( 4): construction--barrier--guard-rail        has instances: False
#                        Barrier ( 5): construction--barrier--other-barrier     has instances: False
#                           Wall ( 6): construction--barrier--wall              has instances: False
#                      Bike Lane ( 7): construction--flat--bike-lane            has instances: False
#              Crosswalk - Plain ( 8): construction--flat--crosswalk-plain      has instances: True
#                       Curb Cut ( 9): construction--flat--curb-cut             has instances: False
#                        Parking (10): construction--flat--parking              has instances: False
#                Pedestrian Area (11): construction--flat--pedestrian-area      has instances: False
#                     Rail Track (12): construction--flat--rail-track           has instances: False
#                           Road (13): construction--flat--road                 has instances: False
#                   Service Lane (14): construction--flat--service-lane         has instances: False
#                       Sidewalk (15): construction--flat--sidewalk             has instances: False
#                         Bridge (16): construction--structure--bridge          has instances: False
#                       Building (17): construction--structure--building        has instances: False
#                         Tunnel (18): construction--structure--tunnel          has instances: False
#                         Person (19): human--person                            has instances: True
#                      Bicyclist (20): human--rider--bicyclist                  has instances: True
#                   Motorcyclist (21): human--rider--motorcyclist               has instances: True
#                    Other Rider (22): human--rider--other-rider                has instances: True
#       Lane Marking - Crosswalk (23): marking--crosswalk-zebra                 has instances: True
#         Lane Marking - General (24): marking--general                         has instances: False
#                       Mountain (25): nature--mountain                         has instances: False
#                           Sand (26): nature--sand                             has instances: False
#                            Sky (27): nature--sky                              has instances: False
#                           Snow (28): nature--snow                             has instances: False
#                        Terrain (29): nature--terrain                          has instances: False
#                     Vegetation (30): nature--vegetation                       has instances: False
#                          Water (31): nature--water                            has instances: False
#                         Banner (32): object--banner                           has instances: True
#                          Bench (33): object--bench                            has instances: True
#                      Bike Rack (34): object--bike-rack                        has instances: True
#                      Billboard (35): object--billboard                        has instances: True
#                    Catch Basin (36): object--catch-basin                      has instances: True
#                    CCTV Camera (37): object--cctv-camera                      has instances: True
#                   Fire Hydrant (38): object--fire-hydrant                     has instances: True
#                   Junction Box (39): object--junction-box                     has instances: True
#                        Mailbox (40): object--mailbox                          has instances: True
#                        Manhole (41): object--manhole                          has instances: True
#                    Phone Booth (42): object--phone-booth                      has instances: True
#                        Pothole (43): object--pothole                          has instances: False
#                   Street Light (44): object--street-light                     has instances: True
#                           Pole (45): object--support--pole                    has instances: True
#             Traffic Sign Frame (46): object--support--traffic-sign-frame      has instances: True
#                   Utility Pole (47): object--support--utility-pole            has instances: True
#                  Traffic Light (48): object--traffic-light                    has instances: True
#            Traffic Sign (Back) (49): object--traffic-sign--back               has instances: True
#           Traffic Sign (Front) (50): object--traffic-sign--front              has instances: True
#                      Trash Can (51): object--trash-can                        has instances: True
#                        Bicycle (52): object--vehicle--bicycle                 has instances: True
#                           Boat (53): object--vehicle--boat                    has instances: True
#                            Bus (54): object--vehicle--bus                     has instances: True
#                            Car (55): object--vehicle--car                     has instances: True
#                        Caravan (56): object--vehicle--caravan                 has instances: True
#                     Motorcycle (57): object--vehicle--motorcycle              has instances: True
#                       On Rails (58): object--vehicle--on-rails                has instances: False
#                  Other Vehicle (59): object--vehicle--other-vehicle           has instances: True
#                        Trailer (60): object--vehicle--trailer                 has instances: True
#                          Truck (61): object--vehicle--truck                   has instances: True
#                   Wheeled Slow (62): object--vehicle--wheeled-slow            has instances: True
#                      Car Mount (63): void--car-mount                          has instances: False
#                    Ego Vehicle (64): void--ego-vehicle                        has instances: False
#                      Unlabeled (65): void--unlabeled                          has instances: False

# %%
for key, value in color_id_map.items():
        print(value)
# Out:
# [3, [165, 42, 42]]
# [3, [0, 192, 0]]
# [8, [196, 196, 196]]
# [2, [190, 153, 153]]
# [2, [180, 165, 180]]
# [3, [90, 120, 150]]
# [11, [102, 102, 156]]
# [8, [128, 64, 255]]
# [7, [140, 140, 200]]
# [8, [170, 170, 170]]
# [7, [250, 170, 160]]
# [8, [96, 96, 96]]
# [0, [230, 150, 140]]
# [7, [128, 64, 128]]
# [7, [110, 110, 110]]
# [8, [244, 35, 232]]
# [0, [150, 100, 100]]
# [1, [70, 70, 70]]
# [0, [150, 120, 90]]
# [4, [220, 20, 60]]
# [4, [255, 0, 0]]
# [10, [255, 0, 100]]
# [10, [255, 0, 200]]
# [6, [200, 128, 128]]
# [6, [255, 255, 255]]
# [0, [64, 170, 64]]
# [0, [230, 160, 50]]
# [0, [70, 130, 180]]
# [0, [190, 255, 255]]
# [0, [152, 251, 152]]
# [9, [107, 142, 35]]
# [0, [0, 170, 30]]
# [3, [255, 255, 128]]
# [3, [250, 0, 30]]
# [3, [100, 140, 180]]
# [3, [220, 220, 220]]
# [3, [220, 128, 128]]
# [3, [222, 40, 40]]
# [3, [100, 170, 30]]
# [3, [40, 40, 40]]
# [3, [33, 33, 33]]
# [7, [100, 128, 160]]
# [3, [142, 0, 0]]
# [7, [70, 100, 150]]
# [5, [210, 170, 100]]
# [5, [153, 153, 153]]
# [12, [128, 128, 128]]
# [5, [0, 0, 80]]
# [12, [250, 170, 30]]
# [12, [192, 192, 192]]
# [12, [220, 220, 0]]
# [3, [140, 140, 20]]
# [3, [119, 11, 32]]
# [3, [150, 0, 255]]
# [10, [0, 60, 100]]
# [10, [0, 0, 142]]
# [10, [0, 0, 90]]
# [10, [0, 0, 230]]
# [0, [0, 80, 100]]
# [10, [128, 64, 64]]
# [10, [0, 0, 110]]
# [10, [0, 0, 70]]
# [10, [0, 0, 192]]
# [0, [32, 32, 32]]
# [0, [120, 10, 10]]
# [0, [0, 0, 0]]

# %%
color_label_val_list = get_img_name(color_label_val)
color_label_train_list = get_img_name(color_label_train)

img_val_list = get_img_name(image_val)
img_train_list = get_img_name(image_train)



print(f'Color label val size: {len(color_label_val_list)}')
print(f'Color  label train size: {len(color_label_train_list)}')
print()
print(f'Img val size size: {len(img_val_list)}')
print(f'Img train size size: {len(img_train_list)}')
print()
print(f'eksmaple path color label: {color_label_train_list[0]}')
print(f'eksmaple path img label: {img_train_list[0]}')
# Out:
# Color label val size: 2000
# Color  label train size: 18000
#
# Img val size size: 2000
# Img train size size: 18000
#
# eksmaple path color label: ../data/mapillary-vistas-dataset_public_v1.1/training/labels/--NSVcUgfVhFd6uzkqHOOg.png
# eksmaple path img label: ../data/mapillary-vistas-dataset_public_v1.1/training/images/--NSVcUgfVhFd6uzkqHOOg.jpg

# %%
img = cv2.cvtColor(cv2.imread(img_train_list[0]), cv2.COLOR_BGR2RGB)
mask = cv2.cvtColor(cv2.imread(color_label_train_list[0]), cv2.COLOR_BGR2RGB)

compare_img(img, mask)

# %%
#tror probleme saa langt er at jeg returnere rgb, skal kun ha 1 array med farger. hmmmm

img, mask = random_augment(img, mask)
compare_img(img, mask)
print(mask.shape)
# Out:
# (2448, 3264, 3)

# %%
'''
from PIL import Image

# convert labeled data to numpy arrays for better handling
base_image = Image.open(img_val_list[0])
label_image= Image.open(color_label_val_list[0])
instance_image = Image.open('mapillary-vistas-dataset_public_v1.1/training/instances/_0A_W6lEi-7W0RvVEiKkyQ.png')
panoptic_image = Image.open('mapillary-vistas-dataset_public_v1.1/training/panoptic/_0R1piHytmNxzCyp5YjF8g.png')

label_array = np.array(label_image)
instance_array = np.array(instance_image, dtype=np.uint16)

# now we split the instance_array into labels and instance ids
instance_label_array = np.array(instance_array / 256, dtype=np.uint8)
instance_ids_array = np.array(instance_array % 256, dtype=np.uint8)


# for visualization, we apply the colors stored in the config
colored_label_array = apply_color_map(label_array, labels)
colored_instance_label_array = apply_color_map(instance_label_array, labels)


# plot the result
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(20,15))

ax[0][0].imshow(base_image)
ax[0][0].get_xaxis().set_visible(False)
ax[0][0].get_yaxis().set_visible(False)
ax[0][0].set_title("Base image")
ax[0][1].imshow(colored_label_array)
ax[0][1].get_xaxis().set_visible(False)
ax[0][1].get_yaxis().set_visible(False)
ax[0][1].set_title("Labels")
ax[1][0].imshow(instance_ids_array)
ax[1][0].get_xaxis().set_visible(False)
ax[1][0].get_yaxis().set_visible(False)
ax[1][0].set_title("Instance IDs")
ax[1][1].imshow(colored_instance_label_array)
ax[1][1].get_xaxis().set_visible(False)
ax[1][1].get_yaxis().set_visible(False)
ax[1][1].set_title("Labels from instance file (identical to labels above)")
ax[2][0].imshow(panoptic_image)
ax[2][0].get_xaxis().set_visible(False)
ax[2][0].get_yaxis().set_visible(False)
ax[2][0].set_title("Labels from panoptic")
ax[2][1].axis('off')

fig.tight_layout()
#fig.plot()
#fig.savefig('MVD_plot.png')
'''
# Out:
# '\nfrom PIL import Image\n\n# convert labeled data to numpy arrays for better handling\nbase_image = Image.open(img_val_list[0])\nlabel_image= Image.open(color_label_val_list[0])\ninstance_image = Image.open(\'mapillary-vistas-dataset_public_v1.1/training/instances/_0A_W6lEi-7W0RvVEiKkyQ.png\')\npanoptic_image = Image.open(\'mapillary-vistas-dataset_public_v1.1/training/panoptic/_0R1piHytmNxzCyp5YjF8g.png\')\n\nlabel_array = np.array(label_image)\ninstance_array = np.array(instance_image, dtype=np.uint16)\n\n# now we split the instance_array into labels and instance ids\ninstance_label_array = np.array(instance_array / 256, dtype=np.uint8)\ninstance_ids_array = np.array(instance_array % 256, dtype=np.uint8)\n\n\n# for visualization, we apply the colors stored in the config\ncolored_label_array = apply_color_map(label_array, labels)\ncolored_instance_label_array = apply_color_map(instance_label_array, labels)\n\n\n# plot the result\nfig, ax = plt.subplots(nrows=3, ncols=2, figsize=(20,15))\n\nax[0][0].imshow(base_image)\nax[0][0].get_xaxis().set_visible(False)\nax[0][0].get_yaxis().set_visible(False)\nax[0][0].set_title("Base image")\nax[0][1].imshow(colored_label_array)\nax[0][1].get_xaxis().set_visible(False)\nax[0][1].get_yaxis().set_visible(False)\nax[0][1].set_title("Labels")\nax[1][0].imshow(instance_ids_array)\nax[1][0].get_xaxis().set_visible(False)\nax[1][0].get_yaxis().set_visible(False)\nax[1][0].set_title("Instance IDs")\nax[1][1].imshow(colored_instance_label_array)\nax[1][1].get_xaxis().set_visible(False)\nax[1][1].get_yaxis().set_visible(False)\nax[1][1].set_title("Labels from instance file (identical to labels above)")\nax[2][0].imshow(panoptic_image)\nax[2][0].get_xaxis().set_visible(False)\nax[2][0].get_yaxis().set_visible(False)\nax[2][0].set_title("Labels from panoptic")\nax[2][1].axis(\'off\')\n\nfig.tight_layout()\n#fig.plot()\n#fig.savefig(\'MVD_plot.png\')\n'

# %%
'''
If we are not using image augmentation we need to reduce the channels.
'''
def labels_to_maskes_reduce(img_label, color_id_map, num_channels):
    num_objects = len(color_id_map.keys())
    
    height = img_label.shape[0]
    width = img_label.shape[1]

    channels = np.zeros((height, width, num_channels), dtype=np.uint8)
    
    for key, value in color_id_map.items():
        mask = (img_label == value[1]).all(-1)

        channels[..., value[0]] = np.logical_or(channels[:,:, value[0]], mask)


    return channels


'''
Image augmentation returnes object that is recuced to city shape colors, therfor 
we need other function to create mask 
'''
def labels_to_maskes(img_label, color_map, num_channels):
    num_objects = len(color_map.keys())
    
    height = img_label.shape[0]
    width = img_label.shape[1]

    channels = np.zeros((height, width, num_channels), dtype=np.uint8)
    
    for key, value in color_map.items():
        mask = (img_label ==  value).all(-1)

        channels[..., key] = np.logical_or(channels[:,:, key], mask)

    return channels

masks = labels_to_maskes(mask, classes_cc, NUM_SEG)

# %%
print(f'mask shape: {masks.shape}')
# Out:
# mask shape: (2448, 3264, 13)

# %%
def maskes_to_labels(maskes):
    #denne maa muligens fjernes
    maskes = (maskes==maskes.max(axis=2, keepdims=1)).astype(np.uint8)
    labels = np.zeros((maskes.shape[0], maskes.shape[1], 3), dtype=np.uint8)
        
    for key, value in classes_cc.items():
        mask = maskes[..., key]
        labels = labels + mask[..., None] * value
    
    return labels 
    
labels = maskes_to_labels(masks)

# %%
compare_img(img, mask)
compare_img(img, labels)

# %%
def batch_generator(image_paths, label_path, color_labels, classes_cc, index_list, batch_size, index=0, training=True):
    
    
    index = index
    label_path_list = label_path
    image_paths_list = image_paths

    while True:
        
        images = []
        #drivable_area = np.array([])#np.ndarray(shape=(IMG_HEIGHT, IMG_WIDTH, NUM_SEG))
        maskes = []
        data_size = len(index_list)
        
        for i in range(batch_size):
            
            #image_id = images_ids.sample()
            
            index += 1
            if index >= data_size:
                index = 0
             
            #index = random.randint(0, data_size)
            img_url = image_paths_list[index_list[index]]
            label_url = label_path_list[index_list[index]]
            
            img = cv2.imread(img_url)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            mask = cv2.imread(label_url)
            mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
            
            img = img_process(img)
            mask = img_process(mask)
            
            if training:
                img, mask = random_augment(img, mask)
                mask = labels_to_maskes(mask, classes_cc, NUM_SEG)
            else:
                mask = labels_to_maskes_reduce(mask, color_labels, NUM_SEG)
            
            images.append(img)
            maskes.append(mask) #.tolist()
            #drivable_area = np.append(drivable_area, rb_img, axis=0)

        yield (np.asarray(images), np.asarray(maskes)) # drivable_area

# %%
x_val_gen, y_val_gen = next(batch_generator(img_val_list, color_label_val_list, color_id_map,classes_cc, [30], 1, training=False))
x_train_gen, y_train_gen = next(batch_generator(img_train_list, color_label_train_list, color_id_map,classes_cc, [5,4], 1))

# %%
y_train_maskes = y_train_gen[0]
print(f'mask shape: {y_train_maskes.shape}')

#compare_img(x_train_gen[0]*255, *255)
# Out:
# mask shape: (480, 640, 13)

# %%
plt.imshow(x_train_gen[0])

# %%
y_train_label = maskes_to_labels(y_train_maskes)
compare_img(x_train_gen[0], y_train_label, 'Image', 'CityScape labels')

# %%
compare_img(x_val_gen[0], maskes_to_labels(y_val_gen[0]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def create_setup(dataset, min_data, max_data, arc):
    dropout = random.uniform(0.1, 0.3)
    print(dropout)
    dropout = round(dropout, 2)
    data_amount = random.randint(min_data, max_data) #np.random.randint(low=min_data, high=max_data)
    
    architecture = arc
    created = round(time.time())
    
    optimizers = ['Adam', 'SGD']#[Adam(lr=1e-3), SGD(lr=1e-3)]
    
    activation_func_list = ['relu', 'elu', 'sigmoid', 'tanh', 'hard_sigmoid', 'selu']
    
    activation_func = np.random.choice(activation_func_list, 1, p=[0.8, 0.05, 0.05, 0.05, 0.02, 0.03])[0]
    optimizer = np.random.choice(optimizers, 1, p=[0.6, 0.4])[0]
    
    training_time = 0
    
    model_info = {}
    name = f'{architecture}_{created}'
    
    model_info[name] = {
        'created': created, 
        'training_time': 0,
        'data_amount': data_amount,
        'architecture': arc,
        'dataset': dataset,
        'notes': 'no modification',
        'activation_func': activation_func,
        'dropout': dropout,
        'optimizer': optimizer,
        'loss': 'binary_crossentropy'
    }
            
    
    return model_info, name
    
    

def save_model(model, name, model_info):
    model.save(f'seg_models/{name}.h5')

    json_file_name = 'model_info.json'

    with open(json_file_name, 'r') as file_reader:
        model_data = json.load(file_reader)

    model_data.update(model_info)
    file_reader.close()

    with open(json_file_name, "w") as file_write:
    # write json data into file
        json.dump(model_data, file_write)
    file_write.close()

# %%
'''
#standard categorical cross entropy
# N data points, C classes
# true - true values. Shape: (N, C)
# Pred - predicted vlaues. Shape: (N, C)
# returns - loss (N)

def categorical_cross_entropy(true, pred):
    return np.sum(true * np.log(pred), axis=1)

# Bayesian categorical cross entropy.
# N data points, C classes, T monte carlo simulations
# true - true values. shape: (N, C)
# pred_var - predicted logit values and variance. Shape: (N, C + 1)
# return - loss (N, )
def bayesian_categorical_crossentropy(T, num_classes):
    def bayesian_vategorical_crossentropy_internal:(true, pred_var):
            # shape: (N, )
            std = K.sqrt(pred_var[:, num_classes:])
            # shape: (N,)
            variance = pred_var[:, num_classes]
            variance_depressor = K.exp(variance) - K.ones_like(variance)
            # shape: (N, C)
            pred = pred_var[:, 0:num_classes]
            # shape: (N, )
            undistorted_loss = K.categorical_cross_entropy(pred, true, from_logits=True)
            # Shape: (T, )
            iterable = K.variable(np.ones(T))
            dist = distributions.Normal(loc=K.zeros_like(std), scale=std)
            monte_carlo_results = K.map_fn(gaussian_categorical_crossentropy(true, pred, dist, undisorted_loss, num_clases), iterable, name='monte_carlo_results')
            
            variance_loss = K.mean(monte_carlo_results, axis=0) * undisorted_loss
            
            return variance_loss + undistorted_loss + variance_depressor
        return bayesian_vategorical_crossentropy_internal
    

# for a simple monte carlo simulation,
#   calculate categorical_crossentropy of
#   predicted logit values plus gaussian
#   noise vs true vaues 
# true - true values. shape: (N, C)
# pred predicted logit values. shape (N, C)
# undistored_loss - the crosenntropy loss whitput variance distortion. Shape: (N,)
# num_classes - the number of classes. C
# returns - total diffreences for all classes (N, )
def gaussian_categorical_crossentropy(true, pred, dist, undistorted_loss, num_classes):
    def map_fn(i):
        std_samples = K.transpose(dist.sample(num_classes))
        distorted_loss = K.categorical_crossentropy(pred+std_samples, true, from_logits=True)
        diff = undistored_loss - distorted_loss
        return -K.elu(diff)
    return map_fn
'''
# Out:
# "\n#standard categorical cross entropy\n# N data points, C classes\n# true - true values. Shape: (N, C)\n# Pred - predicted vlaues. Shape: (N, C)\n# returns - loss (N)\n\ndef categorical_cross_entropy(true, pred):\n    return np.sum(true * np.log(pred), axis=1)\n\n# Bayesian categorical cross entropy.\n# N data points, C classes, T monte carlo simulations\n# true - true values. shape: (N, C)\n# pred_var - predicted logit values and variance. Shape: (N, C + 1)\n# return - loss (N, )\ndef bayesian_categorical_crossentropy(T, num_classes):\n    def bayesian_vategorical_crossentropy_internal:(true, pred_var):\n            # shape: (N, )\n            std = K.sqrt(pred_var[:, num_classes:])\n            # shape: (N,)\n            variance = pred_var[:, num_classes]\n            variance_depressor = K.exp(variance) - K.ones_like(variance)\n            # shape: (N, C)\n            pred = pred_var[:, 0:num_classes]\n            # shape: (N, )\n            undistorted_loss = K.categorical_cross_entropy(pred, true, from_logits=True)\n            # Shape: (T, )\n            iterable = K.variable(np.ones(T))\n            dist = distributions.Normal(loc=K.zeros_like(std), scale=std)\n            monte_carlo_results = K.map_fn(gaussian_categorical_crossentropy(true, pred, dist, undisorted_loss, num_clases), iterable, name='monte_carlo_results')\n            \n            variance_loss = K.mean(monte_carlo_results, axis=0) * undisorted_loss\n            \n            return variance_loss + undistorted_loss + variance_depressor\n        return bayesian_vategorical_crossentropy_internal\n    \n\n# for a simple monte carlo simulation,\n#   calculate categorical_crossentropy of\n#   predicted logit values plus gaussian\n#   noise vs true vaues \n# true - true values. shape: (N, C)\n# pred predicted logit values. shape (N, C)\n# undistored_loss - the crosenntropy loss whitput variance distortion. Shape: (N,)\n# num_classes - the number of classes. C\n# returns - total diffreences for all classes (N, )\ndef gaussian_categorical_crossentropy(true, pred, dist, undistorted_loss, num_classes):\n    def map_fn(i):\n        std_samples = K.transpose(dist.sample(num_classes))\n        distorted_loss = K.categorical_crossentropy(pred+std_samples, true, from_logits=True)\n        diff = undistored_loss - distorted_loss\n        return -K.elu(diff)\n    return map_fn\n"

# %%
def create_model(activation, dropout, mc=True):
    #activation = 'relu'
    #dropout = 0.3 # 0.15
    #mc = True #if droput shoud ocure after training

    img_input = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))#640x480, 320x240

    conv1 = Conv2D(64, (3, 3), activation=activation, padding='same')(img_input)
    conv1 = Dropout(dropout)(conv1, training=mc)
    conv1 = Conv2D(64, (3, 3), activation=activation, padding='same')(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)

    conv2 = Conv2D(128, (3, 3), activation=activation, padding='same')(pool1)
    conv2 = Dropout(dropout)(conv2, training=mc)
    conv2 = Conv2D(128, (3, 3), activation=activation, padding='same')(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)

    conv3 = Conv2D(256, (3, 3), activation=activation, padding='same')(pool2)
    conv3 = Dropout(dropout)(conv3, training=mc)
    conv3 = Conv2D(256, (3, 3), activation=activation, padding='same')(conv3)
    pool3 = MaxPooling2D((2, 2))(conv3)

    conv4 = Conv2D(512, (3, 3), activation=activation, padding='same')(pool3)
    conv4 = Dropout(dropout)(conv4, training=mc)
    conv4 = Conv2D(512, (3, 3), activation=activation, padding='same')(conv4)

    up1 = concatenate([UpSampling2D((2, 2))(conv4), conv3], axis=-1)
    conv5 = Conv2D(256, (3, 3), activation=activation, padding='same')(up1)
    conv5 = Dropout(dropout)(conv5, training=mc)
    conv5 = Conv2D(256, (3, 3), activation=activation, padding='same')(conv5)

    up2 = concatenate([UpSampling2D((2, 2))(conv5), conv2], axis=-1)
    conv6 = Conv2D(128, (3, 3), activation=activation, padding='same')(up2)
    conv6 = Dropout(dropout)(conv6, training=mc)
    conv6 = Conv2D(128, (3, 3), activation=activation, padding='same')(conv6)


    up3 = concatenate([UpSampling2D((2, 2))(conv6), conv1], axis=-1)
    conv7 = Conv2D(64, (3, 3), activation=activation, padding='same')(up3)
    conv7 = Dropout(dropout)(conv7, training=mc)
    conv7 = Conv2D(32, (3, 3), activation=activation, padding='same')(conv7)

    out = Conv2D(NUM_SEG, (1,1), padding='same', activation='sigmoid')(conv7)

    model = Model(inputs=[img_input], outputs=[out])

    #optimizer = Adam(lr=1e-3) #10 epocher er bra på -3
    return model #.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[MeanIoU(num_classes=NUM_SEG)])#'accuracy'

# %%
def create_model_u_nett_small(activation, dropout, mc=True):
    #activation = 'relu'
    #dropout = 0.3 # 0.15
    #mc = True #if droput shoud ocure after training

    img_input = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))#640x480, 320x240

    conv1 = Conv2D(64, (3, 3), activation=activation, padding='same')(img_input)
    conv1 = Dropout(dropout)(conv1, training=mc)
    conv1 = Conv2D(64, (3, 3), activation=activation, padding='same')(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)

    conv2 = Conv2D(128, (3, 3), activation=activation, padding='same')(pool1)
    conv2 = Dropout(dropout)(conv2, training=mc)
    conv2 = Conv2D(128, (3, 3), activation=activation, padding='same')(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)


    conv3 = Conv2D(512, (3, 3), activation=activation, padding='same')(pool2)
    conv3 = Dropout(dropout)(conv3, training=mc)
    conv3 = Conv2D(512, (3, 3), activation=activation, padding='same')(conv3)


    up2 = concatenate([UpSampling2D((2, 2))(conv3), conv2], axis=-1)
    conv4 = Conv2D(128, (3, 3), activation=activation, padding='same')(up2)
    conv4 = Dropout(dropout)(conv4, training=mc)
    conv4 = Conv2D(128, (3, 3), activation=activation, padding='same')(conv4)


    up3 = concatenate([UpSampling2D((2, 2))(conv4), conv1], axis=-1)
    conv5 = Conv2D(64, (3, 3), activation=activation, padding='same')(up3)
    conv5 = Dropout(dropout)(conv5, training=mc)
    conv5 = Conv2D(32, (3, 3), activation=activation, padding='same')(conv5)

    out = Conv2D(NUM_SEG, (1,1), padding='same', activation='sigmoid')(conv5)

    model = Model(inputs=[img_input], outputs=[out])

    #optimizer = Adam(lr=1e-3) #10 epocher er bra på -3
    return model #.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[MeanIoU(num_classes=NUM_SEG)])#'accuracy'

# %%
#model.summary()

# %%
ROUNDS = 20
for round_num in range(ROUNDS):
   
    train_data_size = len(color_label_train_list)
    val_data_size = len(color_label_val_list)
    
    model_info, name = create_setup('map_vista', 30, 100, 'u-net_small')
    activation = model_info[name]['activation_func']
    dropout = model_info[name]['dropout']
    data_amount = model_info[name]['data_amount']
    if model_info[name]['optimizer'] == 'Adam':
        optimizer= Adam(lr=1e-3)
    elif model_info[name]['optimizer'] == 'SGD':
        optimizer = SGD(lr=1e-3)
    
    if False:
        random.seed(0)
        optimizer = Adam(lr=1e-3)
        data_amount = 200
        dropout = 0.15
        activation = 'relu'
    #indexes_train =  np.random.Generator.integers(0, high=train_data_size, size=data_amount, dtype=np.uint8)
    #indexes_val =  np.random.Generator.integers(0, high=val_data_size, size=data_amount//5, dtype=np.uint8)
    
    indexes_train = random.sample(range(0,train_data_size), data_amount)
    indexes_val = random.sample(range(0,val_data_size), data_amount//5)
    
    print(f'activation function: {activation}')
    print(f'dropout:  {dropout}')
    print(f'data amount: {data_amount}')
    
    model = create_model_u_nett_small(activation, dropout)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[MeanIoU(num_classes=NUM_SEG)])#'accuracy'
    #print(f'data amount: {data_amount}')
    if data_amount < 16:
        batch_size=8
    elif data_amount < 32:
        batch_size=16
    else:
        batch_size=32
        
    #amount_data = model_info[name]['amount_data']
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
    batch_size =  1#32 
    stp = ((data_amount) // batch_size)
    history = model.fit(batch_generator(img_train_list, color_label_train_list, color_id_map, classes_cc, indexes_train, batch_size, training= True), 
                                    steps_per_epoch= stp, #stp
                                    epochs=150, #10 hvirker mer en nokk
                                    validation_data=batch_generator(img_val_list, color_label_val_list, color_id_map, classes_cc, indexes_val, 1, training= False), #100
                                    validation_steps=data_amount//5, # 200
                                    verbose=1,
                                    callbacks=[es],
                                    use_multiprocessing=True)
    
    save_model(model, name, model_info)
    print()
    print()
    print(f'round: {round_num + 1} in {ROUNDS}')
    print()
    print()
# Out:
# 0.209599390020775
# activation function: relu
# dropout:  0.21
# data amount: 31
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 31 steps, validate for 6 steps
# Epoch 1/150
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [==============================] - 19s 623ms/step - loss: 2.0290 - mean_io_u: 0.4649 - val_loss: 0.3043 - val_mean_io_u: 0.4617
# Epoch 2/150
# 31/31 [==============================] - 17s 556ms/step - loss: 0.2780 - mean_io_u: 0.4615 - val_loss: 0.2577 - val_mean_io_u: 0.4617
# Epoch 3/150
# 31/31 [==============================] - 16s 508ms/step - loss: 0.2452 - mean_io_u: 0.4615 - val_loss: 0.2375 - val_mean_io_u: 0.4617
# Epoch 4/150
# 31/31 [==============================] - 16s 509ms/step - loss: 0.2294 - mean_io_u: 0.4615 - val_loss: 0.2315 - val_mean_io_u: 0.4617
# Epoch 5/150
# 31/31 [==============================] - 16s 510ms/step - loss: 0.2236 - mean_io_u: 0.4615 - val_loss: 0.2063 - val_mean_io_u: 0.4617
# Epoch 6/150
# 31/31 [==============================] - 16s 509ms/step - loss: 0.2104 - mean_io_u: 0.4615 - val_loss: 0.1948 - val_mean_io_u: 0.4617
# Epoch 7/150
# 31/31 [==============================] - 16s 507ms/step - loss: 0.1981 - mean_io_u: 0.4615 - val_loss: 0.1838 - val_mean_io_u: 0.4617
# Epoch 8/150
# 31/31 [==============================] - 16s 511ms/step - loss: 0.1917 - mean_io_u: 0.4615 - val_loss: 0.1805 - val_mean_io_u: 0.4617
# Epoch 9/150
# 31/31 [==============================] - 16s 510ms/step - loss: 0.1860 - mean_io_u: 0.4615 - val_loss: 0.1720 - val_mean_io_u: 0.4617
# Epoch 10/150
# 31/31 [==============================] - 16s 509ms/step - loss: 0.1838 - mean_io_u: 0.4615 - val_loss: 0.1702 - val_mean_io_u: 0.4617
# Epoch 11/150
# 31/31 [==============================] - 16s 508ms/step - loss: 0.1856 - mean_io_u: 0.4615 - val_loss: 0.1755 - val_mean_io_u: 0.4617
# Epoch 12/150
# 31/31 [==============================] - 16s 509ms/step - loss: 0.1820 - mean_io_u: 0.4615 - val_loss: 0.1696 - val_mean_io_u: 0.4617
# Epoch 13/150
# 31/31 [==============================] - 16s 507ms/step - loss: 0.1791 - mean_io_u: 0.4615 - val_loss: 0.1632 - val_mean_io_u: 0.4617
# Epoch 14/150
# 31/31 [==============================] - 16s 507ms/step - loss: 0.1798 - mean_io_u: 0.4615 - val_loss: 0.1668 - val_mean_io_u: 0.4617
# Epoch 15/150
# 31/31 [==============================] - 16s 508ms/step - loss: 0.1774 - mean_io_u: 0.4615 - val_loss: 0.1601 - val_mean_io_u: 0.4617
# Epoch 16/150
# 31/31 [==============================] - 16s 507ms/step - loss: 0.1814 - mean_io_u: 0.4615 - val_loss: 0.1637 - val_mean_io_u: 0.4617
# Epoch 17/150
# 31/31 [==============================] - 16s 511ms/step - loss: 0.1742 - mean_io_u: 0.4615 - val_loss: 0.1652 - val_mean_io_u: 0.4617
# Epoch 18/150
# 31/31 [==============================] - 16s 513ms/step - loss: 0.1793 - mean_io_u: 0.4615 - val_loss: 0.1584 - val_mean_io_u: 0.4617
# Epoch 19/150
# 31/31 [==============================] - 16s 505ms/step - loss: 0.1766 - mean_io_u: 0.4615 - val_loss: 0.1603 - val_mean_io_u: 0.4617
# Epoch 20/150
# 31/31 [==============================] - 16s 511ms/step - loss: 0.1723 - mean_io_u: 0.4615 - val_loss: 0.1576 - val_mean_io_u: 0.4617
# Epoch 21/150
# 31/31 [==============================] - 16s 510ms/step - loss: 0.1697 - mean_io_u: 0.4615 - val_loss: 0.1582 - val_mean_io_u: 0.4617
# Epoch 22/150
# 31/31 [==============================] - 16s 509ms/step - loss: 0.1737 - mean_io_u: 0.4615 - val_loss: 0.1535 - val_mean_io_u: 0.4617
# Epoch 23/150
# 31/31 [==============================] - 16s 509ms/step - loss: 0.1712 - mean_io_u: 0.4615 - val_loss: 0.1537 - val_mean_io_u: 0.4617
# Epoch 24/150
# 31/31 [==============================] - 16s 509ms/step - loss: 0.1678 - mean_io_u: 0.4615 - val_loss: 0.1499 - val_mean_io_u: 0.4617
# Epoch 25/150
# 31/31 [==============================] - 16s 517ms/step - loss: 0.1673 - mean_io_u: 0.4615 - val_loss: 0.1511 - val_mean_io_u: 0.4617
# Epoch 26/150
# 31/31 [==============================] - 16s 508ms/step - loss: 0.1705 - mean_io_u: 0.4615 - val_loss: 0.1510 - val_mean_io_u: 0.4617
# Epoch 27/150
# 31/31 [==============================] - 16s 509ms/step - loss: 0.1699 - mean_io_u: 0.4615 - val_loss: 0.1971 - val_mean_io_u: 0.4617
# Epoch 28/150
# 31/31 [==============================] - 16s 506ms/step - loss: 0.1698 - mean_io_u: 0.4615 - val_loss: 0.1588 - val_mean_io_u: 0.4617
# Epoch 29/150
# 31/31 [==============================] - 16s 509ms/step - loss: 0.1714 - mean_io_u: 0.4615 - val_loss: 0.1525 - val_mean_io_u: 0.4617
# Epoch 00029: early stopping
#
#
# round: 1 in 20
#
#
# 0.16988055597811885
# activation function: relu
# dropout:  0.17
# data amount: 86
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 86 steps, validate for 17 steps
# Epoch 1/150
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 86/86 [==============================] - 51s 598ms/step - loss: 0.8081 - mean_io_u_1: 0.4630 - val_loss: 0.2442 - val_mean_io_u_1: 0.4618
# Epoch 2/150
# 86/86 [==============================] - 45s 519ms/step - loss: 0.2450 - mean_io_u_1: 0.4615 - val_loss: 0.2276 - val_mean_io_u_1: 0.4618
# Epoch 3/150
# 86/86 [==============================] - 45s 520ms/step - loss: 0.2113 - mean_io_u_1: 0.4615 - val_loss: 0.1965 - val_mean_io_u_1: 0.4618
# Epoch 4/150
# 86/86 [==============================] - 45s 520ms/step - loss: 0.1981 - mean_io_u_1: 0.4615 - val_loss: 0.1905 - val_mean_io_u_1: 0.4618
# Epoch 5/150
# 86/86 [==============================] - 44s 517ms/step - loss: 0.1933 - mean_io_u_1: 0.4615 - val_loss: 0.1857 - val_mean_io_u_1: 0.4618
# Epoch 6/150
# 86/86 [==============================] - 44s 517ms/step - loss: 0.1883 - mean_io_u_1: 0.4615 - val_loss: 0.1858 - val_mean_io_u_1: 0.4618
# Epoch 7/150
# 86/86 [==============================] - 45s 519ms/step - loss: 0.1850 - mean_io_u_1: 0.4615 - val_loss: 0.1838 - val_mean_io_u_1: 0.4618
# Epoch 8/150
# 86/86 [==============================] - 45s 518ms/step - loss: 0.1833 - mean_io_u_1: 0.4615 - val_loss: 0.1830 - val_mean_io_u_1: 0.4618
# Epoch 9/150
# 86/86 [==============================] - 45s 518ms/step - loss: 0.1775 - mean_io_u_1: 0.4615 - val_loss: 0.1813 - val_mean_io_u_1: 0.4618
# Epoch 10/150
# 86/86 [==============================] - 45s 518ms/step - loss: 0.1770 - mean_io_u_1: 0.4615 - val_loss: 0.1838 - val_mean_io_u_1: 0.4618
# Epoch 11/150
# 86/86 [==============================] - 45s 519ms/step - loss: 0.1794 - mean_io_u_1: 0.4615 - val_loss: 0.1840 - val_mean_io_u_1: 0.4618
# Epoch 12/150
# 86/86 [==============================] - 45s 520ms/step - loss: 0.1796 - mean_io_u_1: 0.4615 - val_loss: 0.1771 - val_mean_io_u_1: 0.4618
# Epoch 13/150
# 86/86 [==============================] - 45s 521ms/step - loss: 0.1744 - mean_io_u_1: 0.4615 - val_loss: 0.1859 - val_mean_io_u_1: 0.4618
# Epoch 14/150
# 86/86 [==============================] - 45s 520ms/step - loss: 0.1835 - mean_io_u_1: 0.4615 - val_loss: 0.1731 - val_mean_io_u_1: 0.4618
# Epoch 15/150
# 86/86 [==============================] - 45s 519ms/step - loss: 0.1784 - mean_io_u_1: 0.4615 - val_loss: 0.1734 - val_mean_io_u_1: 0.4618
# Epoch 16/150
# 86/86 [==============================] - 44s 517ms/step - loss: 0.1775 - mean_io_u_1: 0.4615 - val_loss: 0.2048 - val_mean_io_u_1: 0.4618
# Epoch 17/150
# 86/86 [==============================] - 45s 520ms/step - loss: 0.1704 - mean_io_u_1: 0.4615 - val_loss: 0.1807 - val_mean_io_u_1: 0.4618
# Epoch 18/150
# 86/86 [==============================] - 45s 521ms/step - loss: 0.1720 - mean_io_u_1: 0.4615 - val_loss: 0.1749 - val_mean_io_u_1: 0.4618
# Epoch 19/150
# 86/86 [==============================] - 45s 518ms/step - loss: 0.1724 - mean_io_u_1: 0.4615 - val_loss: 0.1752 - val_mean_io_u_1: 0.4618
# Epoch 00019: early stopping
#
#
# round: 2 in 20
#
#
# 0.23006233574193521
# activation function: selu
# dropout:  0.23
# data amount: 87
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 87 steps, validate for 17 steps
# Epoch 1/150
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 87/87 [==============================] - 51s 588ms/step - loss: 0.6872 - mean_io_u_2: 0.4659 - val_loss: 0.4908 - val_mean_io_u_2: 0.4632
# Epoch 2/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.3831 - mean_io_u_2: 0.4618 - val_loss: 0.3871 - val_mean_io_u_2: 0.4620
# Epoch 3/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.3202 - mean_io_u_2: 0.4616 - val_loss: 0.3358 - val_mean_io_u_2: 0.4619
# Epoch 4/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.2875 - mean_io_u_2: 0.4616 - val_loss: 0.3036 - val_mean_io_u_2: 0.4619
# Epoch 5/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.2642 - mean_io_u_2: 0.4616 - val_loss: 0.2825 - val_mean_io_u_2: 0.4618
# Epoch 6/150
# 87/87 [==============================] - 45s 515ms/step - loss: 0.2505 - mean_io_u_2: 0.4616 - val_loss: 0.2697 - val_mean_io_u_2: 0.4618
# Epoch 7/150
# 87/87 [==============================] - 44s 511ms/step - loss: 0.2424 - mean_io_u_2: 0.4616 - val_loss: 0.2574 - val_mean_io_u_2: 0.4618
# Epoch 8/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.2328 - mean_io_u_2: 0.4616 - val_loss: 0.2501 - val_mean_io_u_2: 0.4618
# Epoch 9/150
# 87/87 [==============================] - 45s 515ms/step - loss: 0.2259 - mean_io_u_2: 0.4615 - val_loss: 0.2412 - val_mean_io_u_2: 0.4618
# Epoch 10/150
# 87/87 [==============================] - 44s 510ms/step - loss: 0.2193 - mean_io_u_2: 0.4615 - val_loss: 0.2365 - val_mean_io_u_2: 0.4618
# Epoch 11/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.2187 - mean_io_u_2: 0.4615 - val_loss: 0.2329 - val_mean_io_u_2: 0.4618
# Epoch 12/150
# 87/87 [==============================] - 45s 515ms/step - loss: 0.2141 - mean_io_u_2: 0.4615 - val_loss: 0.2285 - val_mean_io_u_2: 0.4618
# Epoch 13/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.2108 - mean_io_u_2: 0.4615 - val_loss: 0.2249 - val_mean_io_u_2: 0.4618
# Epoch 14/150
# 87/87 [==============================] - 44s 510ms/step - loss: 0.2075 - mean_io_u_2: 0.4615 - val_loss: 0.2218 - val_mean_io_u_2: 0.4618
# Epoch 15/150
# 87/87 [==============================] - 46s 524ms/step - loss: 0.2044 - mean_io_u_2: 0.4615 - val_loss: 0.2191 - val_mean_io_u_2: 0.4618
# Epoch 16/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.2031 - mean_io_u_2: 0.4615 - val_loss: 0.2162 - val_mean_io_u_2: 0.4618
# Epoch 17/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1992 - mean_io_u_2: 0.4615 - val_loss: 0.2131 - val_mean_io_u_2: 0.4618
# Epoch 18/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1986 - mean_io_u_2: 0.4615 - val_loss: 0.2123 - val_mean_io_u_2: 0.4618
# Epoch 19/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1966 - mean_io_u_2: 0.4615 - val_loss: 0.2104 - val_mean_io_u_2: 0.4618
# Epoch 20/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1952 - mean_io_u_2: 0.4615 - val_loss: 0.2093 - val_mean_io_u_2: 0.4618
# Epoch 21/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1937 - mean_io_u_2: 0.4615 - val_loss: 0.2077 - val_mean_io_u_2: 0.4618
# Epoch 22/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1948 - mean_io_u_2: 0.4615 - val_loss: 0.2077 - val_mean_io_u_2: 0.4618
# Epoch 23/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1922 - mean_io_u_2: 0.4615 - val_loss: 0.2043 - val_mean_io_u_2: 0.4618
# Epoch 24/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1911 - mean_io_u_2: 0.4615 - val_loss: 0.2055 - val_mean_io_u_2: 0.4618
# Epoch 25/150
# 87/87 [==============================] - 45s 515ms/step - loss: 0.1902 - mean_io_u_2: 0.4615 - val_loss: 0.2029 - val_mean_io_u_2: 0.4618
# Epoch 26/150
# 87/87 [==============================] - 44s 510ms/step - loss: 0.1879 - mean_io_u_2: 0.4615 - val_loss: 0.2032 - val_mean_io_u_2: 0.4618
# Epoch 27/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1891 - mean_io_u_2: 0.4615 - val_loss: 0.2007 - val_mean_io_u_2: 0.4618
# Epoch 28/150
# 87/87 [==============================] - 45s 516ms/step - loss: 0.1874 - mean_io_u_2: 0.4615 - val_loss: 0.2022 - val_mean_io_u_2: 0.4618
# Epoch 29/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1849 - mean_io_u_2: 0.4615 - val_loss: 0.1994 - val_mean_io_u_2: 0.4618
# Epoch 30/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1839 - mean_io_u_2: 0.4615 - val_loss: 0.1996 - val_mean_io_u_2: 0.4618
# Epoch 31/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1855 - mean_io_u_2: 0.4615 - val_loss: 0.1979 - val_mean_io_u_2: 0.4618
# Epoch 32/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1850 - mean_io_u_2: 0.4615 - val_loss: 0.1970 - val_mean_io_u_2: 0.4618
# Epoch 33/150
# 87/87 [==============================] - 45s 516ms/step - loss: 0.1820 - mean_io_u_2: 0.4615 - val_loss: 0.1960 - val_mean_io_u_2: 0.4618
# Epoch 34/150
# 87/87 [==============================] - 44s 511ms/step - loss: 0.1827 - mean_io_u_2: 0.4615 - val_loss: 0.1964 - val_mean_io_u_2: 0.4618
# Epoch 35/150
# 87/87 [==============================] - 44s 511ms/step - loss: 0.1821 - mean_io_u_2: 0.4615 - val_loss: 0.1956 - val_mean_io_u_2: 0.4618
# Epoch 36/150
# 87/87 [==============================] - 44s 509ms/step - loss: 0.1803 - mean_io_u_2: 0.4615 - val_loss: 0.1946 - val_mean_io_u_2: 0.4618
# Epoch 37/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1814 - mean_io_u_2: 0.4615 - val_loss: 0.1934 - val_mean_io_u_2: 0.4618
# Epoch 38/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1793 - mean_io_u_2: 0.4615 - val_loss: 0.1952 - val_mean_io_u_2: 0.4618
# Epoch 39/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1806 - mean_io_u_2: 0.4615 - val_loss: 0.1937 - val_mean_io_u_2: 0.4618
# Epoch 40/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1783 - mean_io_u_2: 0.4615 - val_loss: 0.1922 - val_mean_io_u_2: 0.4618
# Epoch 41/150
# 87/87 [==============================] - 45s 515ms/step - loss: 0.1787 - mean_io_u_2: 0.4615 - val_loss: 0.1913 - val_mean_io_u_2: 0.4618
# Epoch 42/150
# 87/87 [==============================] - 44s 509ms/step - loss: 0.1787 - mean_io_u_2: 0.4615 - val_loss: 0.1922 - val_mean_io_u_2: 0.4618
# Epoch 43/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1779 - mean_io_u_2: 0.4615 - val_loss: 0.1915 - val_mean_io_u_2: 0.4618
# Epoch 44/150
# 87/87 [==============================] - 44s 511ms/step - loss: 0.1761 - mean_io_u_2: 0.4615 - val_loss: 0.1909 - val_mean_io_u_2: 0.4618
# Epoch 45/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1795 - mean_io_u_2: 0.4615 - val_loss: 0.1893 - val_mean_io_u_2: 0.4618
# Epoch 46/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1774 - mean_io_u_2: 0.4615 - val_loss: 0.1902 - val_mean_io_u_2: 0.4618
# Epoch 47/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1787 - mean_io_u_2: 0.4615 - val_loss: 0.1906 - val_mean_io_u_2: 0.4618
# Epoch 48/150
# 87/87 [==============================] - 44s 511ms/step - loss: 0.1751 - mean_io_u_2: 0.4615 - val_loss: 0.1876 - val_mean_io_u_2: 0.4618
# Epoch 49/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1773 - mean_io_u_2: 0.4615 - val_loss: 0.1884 - val_mean_io_u_2: 0.4618
# Epoch 50/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1772 - mean_io_u_2: 0.4615 - val_loss: 0.1883 - val_mean_io_u_2: 0.4618
# Epoch 51/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1749 - mean_io_u_2: 0.4615 - val_loss: 0.1875 - val_mean_io_u_2: 0.4618
# Epoch 52/150
# 87/87 [==============================] - 45s 518ms/step - loss: 0.1752 - mean_io_u_2: 0.4615 - val_loss: 0.1885 - val_mean_io_u_2: 0.4618
# Epoch 53/150
# 87/87 [==============================] - 44s 510ms/step - loss: 0.1736 - mean_io_u_2: 0.4615 - val_loss: 0.1868 - val_mean_io_u_2: 0.4618
# Epoch 54/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1741 - mean_io_u_2: 0.4615 - val_loss: 0.1871 - val_mean_io_u_2: 0.4618
# Epoch 55/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1749 - mean_io_u_2: 0.4615 - val_loss: 0.1859 - val_mean_io_u_2: 0.4618
# Epoch 56/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1716 - mean_io_u_2: 0.4615 - val_loss: 0.1859 - val_mean_io_u_2: 0.4618
# Epoch 57/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1710 - mean_io_u_2: 0.4615 - val_loss: 0.1849 - val_mean_io_u_2: 0.4618
# Epoch 58/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1736 - mean_io_u_2: 0.4615 - val_loss: 0.1848 - val_mean_io_u_2: 0.4618
# Epoch 59/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1727 - mean_io_u_2: 0.4615 - val_loss: 0.1853 - val_mean_io_u_2: 0.4618
# Epoch 60/150
# 87/87 [==============================] - 45s 515ms/step - loss: 0.1741 - mean_io_u_2: 0.4615 - val_loss: 0.1843 - val_mean_io_u_2: 0.4618
# Epoch 61/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1711 - mean_io_u_2: 0.4615 - val_loss: 0.1849 - val_mean_io_u_2: 0.4618
# Epoch 62/150
# 87/87 [==============================] - 45s 515ms/step - loss: 0.1726 - mean_io_u_2: 0.4615 - val_loss: 0.1838 - val_mean_io_u_2: 0.4618
# Epoch 63/150
# 87/87 [==============================] - 45s 515ms/step - loss: 0.1702 - mean_io_u_2: 0.4615 - val_loss: 0.1859 - val_mean_io_u_2: 0.4618
# Epoch 64/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1709 - mean_io_u_2: 0.4615 - val_loss: 0.1834 - val_mean_io_u_2: 0.4618
# Epoch 65/150
# 87/87 [==============================] - 44s 510ms/step - loss: 0.1699 - mean_io_u_2: 0.4615 - val_loss: 0.1843 - val_mean_io_u_2: 0.4618
# Epoch 66/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1714 - mean_io_u_2: 0.4615 - val_loss: 0.1842 - val_mean_io_u_2: 0.4618
# Epoch 67/150
# 87/87 [==============================] - 45s 514ms/step - loss: 0.1704 - mean_io_u_2: 0.4615 - val_loss: 0.1821 - val_mean_io_u_2: 0.4618
# Epoch 68/150
# 87/87 [==============================] - 45s 515ms/step - loss: 0.1702 - mean_io_u_2: 0.4615 - val_loss: 0.1820 - val_mean_io_u_2: 0.4618
# Epoch 69/150
# 87/87 [==============================] - 44s 511ms/step - loss: 0.1708 - mean_io_u_2: 0.4615 - val_loss: 0.1823 - val_mean_io_u_2: 0.4618
# Epoch 70/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1706 - mean_io_u_2: 0.4615 - val_loss: 0.1824 - val_mean_io_u_2: 0.4618
# Epoch 71/150
# 87/87 [==============================] - 45s 512ms/step - loss: 0.1716 - mean_io_u_2: 0.4615 - val_loss: 0.1827 - val_mean_io_u_2: 0.4618
# Epoch 72/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1691 - mean_io_u_2: 0.4615 - val_loss: 0.1822 - val_mean_io_u_2: 0.4618
# Epoch 73/150
# 87/87 [==============================] - 45s 513ms/step - loss: 0.1698 - mean_io_u_2: 0.4615 - val_loss: 0.1821 - val_mean_io_u_2: 0.4618
# Epoch 00073: early stopping
#
#
# round: 3 in 20
#
#
# 0.11855030232370155
# activation function: relu
# dropout:  0.12
# data amount: 67
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 67 steps, validate for 13 steps
# Epoch 1/150
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 67/67 [==============================] - 40s 591ms/step - loss: 0.9315 - mean_io_u_3: 0.4606 - val_loss: 0.5369 - val_mean_io_u_3: 0.4618
# Epoch 2/150
# 67/67 [==============================] - 34s 511ms/step - loss: 0.4663 - mean_io_u_3: 0.4615 - val_loss: 0.4105 - val_mean_io_u_3: 0.4618
# Epoch 3/150
# 67/67 [==============================] - 34s 515ms/step - loss: 0.3556 - mean_io_u_3: 0.4615 - val_loss: 0.3408 - val_mean_io_u_3: 0.4618
# Epoch 4/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.3051 - mean_io_u_3: 0.4615 - val_loss: 0.3114 - val_mean_io_u_3: 0.4618
# Epoch 5/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.2829 - mean_io_u_3: 0.4615 - val_loss: 0.2960 - val_mean_io_u_3: 0.4618
# Epoch 6/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.2694 - mean_io_u_3: 0.4615 - val_loss: 0.2871 - val_mean_io_u_3: 0.4618
# Epoch 7/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.2605 - mean_io_u_3: 0.4615 - val_loss: 0.2801 - val_mean_io_u_3: 0.4618
# Epoch 8/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.2519 - mean_io_u_3: 0.4615 - val_loss: 0.2759 - val_mean_io_u_3: 0.4618
# Epoch 9/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.2502 - mean_io_u_3: 0.4615 - val_loss: 0.2718 - val_mean_io_u_3: 0.4618
# Epoch 10/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.2458 - mean_io_u_3: 0.4615 - val_loss: 0.2677 - val_mean_io_u_3: 0.4618
# Epoch 11/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.2429 - mean_io_u_3: 0.4615 - val_loss: 0.2640 - val_mean_io_u_3: 0.4618
# Epoch 12/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.2386 - mean_io_u_3: 0.4615 - val_loss: 0.2613 - val_mean_io_u_3: 0.4618
# Epoch 13/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.2360 - mean_io_u_3: 0.4615 - val_loss: 0.2594 - val_mean_io_u_3: 0.4618
# Epoch 14/150
# 67/67 [==============================] - 35s 521ms/step - loss: 0.2352 - mean_io_u_3: 0.4615 - val_loss: 0.2567 - val_mean_io_u_3: 0.4618
# Epoch 15/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.2319 - mean_io_u_3: 0.4615 - val_loss: 0.2547 - val_mean_io_u_3: 0.4618
# Epoch 16/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.2262 - mean_io_u_3: 0.4615 - val_loss: 0.2533 - val_mean_io_u_3: 0.4618
# Epoch 17/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.2267 - mean_io_u_3: 0.4615 - val_loss: 0.2511 - val_mean_io_u_3: 0.4618
# Epoch 18/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.2237 - mean_io_u_3: 0.4615 - val_loss: 0.2498 - val_mean_io_u_3: 0.4618
# Epoch 19/150
# 67/67 [==============================] - 34s 513ms/step - loss: 0.2242 - mean_io_u_3: 0.4615 - val_loss: 0.2482 - val_mean_io_u_3: 0.4618
# Epoch 20/150
# 67/67 [==============================] - 34s 515ms/step - loss: 0.2254 - mean_io_u_3: 0.4615 - val_loss: 0.2464 - val_mean_io_u_3: 0.4618
# Epoch 21/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.2191 - mean_io_u_3: 0.4615 - val_loss: 0.2447 - val_mean_io_u_3: 0.4618
# Epoch 22/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.2190 - mean_io_u_3: 0.4615 - val_loss: 0.2436 - val_mean_io_u_3: 0.4618
# Epoch 23/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.2177 - mean_io_u_3: 0.4615 - val_loss: 0.2427 - val_mean_io_u_3: 0.4618
# Epoch 24/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.2189 - mean_io_u_3: 0.4615 - val_loss: 0.2411 - val_mean_io_u_3: 0.4618
# Epoch 25/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.2188 - mean_io_u_3: 0.4615 - val_loss: 0.2403 - val_mean_io_u_3: 0.4618
# Epoch 26/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.2156 - mean_io_u_3: 0.4615 - val_loss: 0.2392 - val_mean_io_u_3: 0.4618
# Epoch 27/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.2148 - mean_io_u_3: 0.4615 - val_loss: 0.2383 - val_mean_io_u_3: 0.4618
# Epoch 28/150
# 67/67 [==============================] - 35s 521ms/step - loss: 0.2134 - mean_io_u_3: 0.4615 - val_loss: 0.2372 - val_mean_io_u_3: 0.4618
# Epoch 29/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.2113 - mean_io_u_3: 0.4615 - val_loss: 0.2365 - val_mean_io_u_3: 0.4618
# Epoch 30/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.2121 - mean_io_u_3: 0.4615 - val_loss: 0.2350 - val_mean_io_u_3: 0.4618
# Epoch 31/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.2104 - mean_io_u_3: 0.4615 - val_loss: 0.2344 - val_mean_io_u_3: 0.4618
# Epoch 32/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.2089 - mean_io_u_3: 0.4615 - val_loss: 0.2337 - val_mean_io_u_3: 0.4618
# Epoch 33/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.2074 - mean_io_u_3: 0.4615 - val_loss: 0.2327 - val_mean_io_u_3: 0.4618
# Epoch 34/150
# 67/67 [==============================] - 34s 513ms/step - loss: 0.2084 - mean_io_u_3: 0.4615 - val_loss: 0.2320 - val_mean_io_u_3: 0.4618
# Epoch 35/150
# 67/67 [==============================] - 35s 520ms/step - loss: 0.2082 - mean_io_u_3: 0.4615 - val_loss: 0.2310 - val_mean_io_u_3: 0.4618
# Epoch 36/150
# 67/67 [==============================] - 34s 515ms/step - loss: 0.2074 - mean_io_u_3: 0.4615 - val_loss: 0.2303 - val_mean_io_u_3: 0.4618
# Epoch 37/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.2066 - mean_io_u_3: 0.4615 - val_loss: 0.2295 - val_mean_io_u_3: 0.4618
# Epoch 38/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.2066 - mean_io_u_3: 0.4615 - val_loss: 0.2291 - val_mean_io_u_3: 0.4618
# Epoch 39/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.2057 - mean_io_u_3: 0.4615 - val_loss: 0.2284 - val_mean_io_u_3: 0.4618
# Epoch 40/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.2044 - mean_io_u_3: 0.4615 - val_loss: 0.2279 - val_mean_io_u_3: 0.4618
# Epoch 41/150
# 67/67 [==============================] - 34s 515ms/step - loss: 0.2047 - mean_io_u_3: 0.4615 - val_loss: 0.2271 - val_mean_io_u_3: 0.4618
# Epoch 42/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.2040 - mean_io_u_3: 0.4615 - val_loss: 0.2266 - val_mean_io_u_3: 0.4618
# Epoch 43/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.2037 - mean_io_u_3: 0.4615 - val_loss: 0.2261 - val_mean_io_u_3: 0.4618
# Epoch 44/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.2032 - mean_io_u_3: 0.4615 - val_loss: 0.2255 - val_mean_io_u_3: 0.4618
# Epoch 45/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.2039 - mean_io_u_3: 0.4615 - val_loss: 0.2248 - val_mean_io_u_3: 0.4618
# Epoch 46/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.2011 - mean_io_u_3: 0.4615 - val_loss: 0.2243 - val_mean_io_u_3: 0.4618
# Epoch 47/150
# 67/67 [==============================] - 34s 515ms/step - loss: 0.2009 - mean_io_u_3: 0.4615 - val_loss: 0.2239 - val_mean_io_u_3: 0.4618
# Epoch 48/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.2019 - mean_io_u_3: 0.4615 - val_loss: 0.2234 - val_mean_io_u_3: 0.4618
# Epoch 49/150
# 67/67 [==============================] - 35s 520ms/step - loss: 0.1998 - mean_io_u_3: 0.4615 - val_loss: 0.2229 - val_mean_io_u_3: 0.4618
# Epoch 50/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.2016 - mean_io_u_3: 0.4615 - val_loss: 0.2224 - val_mean_io_u_3: 0.4618
# Epoch 51/150
# 67/67 [==============================] - 34s 512ms/step - loss: 0.1998 - mean_io_u_3: 0.4615 - val_loss: 0.2221 - val_mean_io_u_3: 0.4618
# Epoch 52/150
# 67/67 [==============================] - 35s 520ms/step - loss: 0.1992 - mean_io_u_3: 0.4615 - val_loss: 0.2215 - val_mean_io_u_3: 0.4618
# Epoch 53/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.1981 - mean_io_u_3: 0.4615 - val_loss: 0.2212 - val_mean_io_u_3: 0.4618
# Epoch 54/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1988 - mean_io_u_3: 0.4615 - val_loss: 0.2207 - val_mean_io_u_3: 0.4618
# Epoch 55/150
# 67/67 [==============================] - 34s 513ms/step - loss: 0.1980 - mean_io_u_3: 0.4615 - val_loss: 0.2203 - val_mean_io_u_3: 0.4618
# Epoch 56/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1965 - mean_io_u_3: 0.4615 - val_loss: 0.2197 - val_mean_io_u_3: 0.4618
# Epoch 57/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.1987 - mean_io_u_3: 0.4615 - val_loss: 0.2193 - val_mean_io_u_3: 0.4618
# Epoch 58/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1963 - mean_io_u_3: 0.4615 - val_loss: 0.2191 - val_mean_io_u_3: 0.4618
# Epoch 59/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.1963 - mean_io_u_3: 0.4615 - val_loss: 0.2184 - val_mean_io_u_3: 0.4618
# Epoch 60/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1968 - mean_io_u_3: 0.4615 - val_loss: 0.2181 - val_mean_io_u_3: 0.4618
# Epoch 61/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.1961 - mean_io_u_3: 0.4615 - val_loss: 0.2177 - val_mean_io_u_3: 0.4618
# Epoch 62/150
# 67/67 [==============================] - 34s 513ms/step - loss: 0.1964 - mean_io_u_3: 0.4615 - val_loss: 0.2174 - val_mean_io_u_3: 0.4618
# Epoch 63/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.1946 - mean_io_u_3: 0.4615 - val_loss: 0.2172 - val_mean_io_u_3: 0.4618
# Epoch 64/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1954 - mean_io_u_3: 0.4615 - val_loss: 0.2164 - val_mean_io_u_3: 0.4618
# Epoch 65/150
# 67/67 [==============================] - 34s 515ms/step - loss: 0.1962 - mean_io_u_3: 0.4615 - val_loss: 0.2163 - val_mean_io_u_3: 0.4618
# Epoch 66/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.1941 - mean_io_u_3: 0.4615 - val_loss: 0.2156 - val_mean_io_u_3: 0.4618
# Epoch 67/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.1937 - mean_io_u_3: 0.4615 - val_loss: 0.2155 - val_mean_io_u_3: 0.4618
# Epoch 68/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1928 - mean_io_u_3: 0.4615 - val_loss: 0.2151 - val_mean_io_u_3: 0.4618
# Epoch 69/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1933 - mean_io_u_3: 0.4615 - val_loss: 0.2150 - val_mean_io_u_3: 0.4618
# Epoch 70/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.1937 - mean_io_u_3: 0.4615 - val_loss: 0.2147 - val_mean_io_u_3: 0.4618
# Epoch 71/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.1908 - mean_io_u_3: 0.4615 - val_loss: 0.2145 - val_mean_io_u_3: 0.4618
# Epoch 72/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1924 - mean_io_u_3: 0.4615 - val_loss: 0.2142 - val_mean_io_u_3: 0.4618
# Epoch 73/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1923 - mean_io_u_3: 0.4615 - val_loss: 0.2136 - val_mean_io_u_3: 0.4618
# Epoch 74/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1925 - mean_io_u_3: 0.4615 - val_loss: 0.2135 - val_mean_io_u_3: 0.4618
# Epoch 75/150
# 67/67 [==============================] - 34s 511ms/step - loss: 0.1903 - mean_io_u_3: 0.4615 - val_loss: 0.2130 - val_mean_io_u_3: 0.4618
# Epoch 76/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1930 - mean_io_u_3: 0.4615 - val_loss: 0.2125 - val_mean_io_u_3: 0.4618
# Epoch 77/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1891 - mean_io_u_3: 0.4615 - val_loss: 0.2126 - val_mean_io_u_3: 0.4618
# Epoch 78/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1917 - mean_io_u_3: 0.4615 - val_loss: 0.2121 - val_mean_io_u_3: 0.4618
# Epoch 79/150
# 67/67 [==============================] - 34s 512ms/step - loss: 0.1914 - mean_io_u_3: 0.4615 - val_loss: 0.2118 - val_mean_io_u_3: 0.4618
# Epoch 80/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1910 - mean_io_u_3: 0.4615 - val_loss: 0.2116 - val_mean_io_u_3: 0.4618
# Epoch 81/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.1906 - mean_io_u_3: 0.4615 - val_loss: 0.2112 - val_mean_io_u_3: 0.4618
# Epoch 82/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1904 - mean_io_u_3: 0.4615 - val_loss: 0.2110 - val_mean_io_u_3: 0.4618
# Epoch 83/150
# 67/67 [==============================] - 34s 515ms/step - loss: 0.1898 - mean_io_u_3: 0.4615 - val_loss: 0.2109 - val_mean_io_u_3: 0.4618
# Epoch 84/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.1892 - mean_io_u_3: 0.4615 - val_loss: 0.2108 - val_mean_io_u_3: 0.4618
# Epoch 85/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.1892 - mean_io_u_3: 0.4615 - val_loss: 0.2104 - val_mean_io_u_3: 0.4618
# Epoch 86/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1894 - mean_io_u_3: 0.4615 - val_loss: 0.2104 - val_mean_io_u_3: 0.4618
# Epoch 87/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.1888 - mean_io_u_3: 0.4615 - val_loss: 0.2099 - val_mean_io_u_3: 0.4618
# Epoch 88/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.1894 - mean_io_u_3: 0.4615 - val_loss: 0.2098 - val_mean_io_u_3: 0.4618
# Epoch 89/150
# 67/67 [==============================] - 34s 515ms/step - loss: 0.1890 - mean_io_u_3: 0.4615 - val_loss: 0.2096 - val_mean_io_u_3: 0.4618
# Epoch 90/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.1888 - mean_io_u_3: 0.4615 - val_loss: 0.2091 - val_mean_io_u_3: 0.4618
# Epoch 91/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.1876 - mean_io_u_3: 0.4615 - val_loss: 0.2088 - val_mean_io_u_3: 0.4618
# Epoch 92/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1863 - mean_io_u_3: 0.4615 - val_loss: 0.2089 - val_mean_io_u_3: 0.4618
# Epoch 93/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1873 - mean_io_u_3: 0.4615 - val_loss: 0.2086 - val_mean_io_u_3: 0.4618
# Epoch 94/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.1867 - mean_io_u_3: 0.4615 - val_loss: 0.2085 - val_mean_io_u_3: 0.4618
# Epoch 95/150
# 67/67 [==============================] - 34s 513ms/step - loss: 0.1859 - mean_io_u_3: 0.4615 - val_loss: 0.2080 - val_mean_io_u_3: 0.4618
# Epoch 96/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1871 - mean_io_u_3: 0.4615 - val_loss: 0.2079 - val_mean_io_u_3: 0.4618
# Epoch 97/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1874 - mean_io_u_3: 0.4615 - val_loss: 0.2077 - val_mean_io_u_3: 0.4618
# Epoch 98/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.1878 - mean_io_u_3: 0.4615 - val_loss: 0.2075 - val_mean_io_u_3: 0.4618
# Epoch 99/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1863 - mean_io_u_3: 0.4615 - val_loss: 0.2072 - val_mean_io_u_3: 0.4618
# Epoch 100/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1876 - mean_io_u_3: 0.4615 - val_loss: 0.2067 - val_mean_io_u_3: 0.4618
# Epoch 101/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.1867 - mean_io_u_3: 0.4615 - val_loss: 0.2066 - val_mean_io_u_3: 0.4618
# Epoch 102/150
# 67/67 [==============================] - 35s 517ms/step - loss: 0.1860 - mean_io_u_3: 0.4615 - val_loss: 0.2066 - val_mean_io_u_3: 0.4618
# Epoch 103/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1858 - mean_io_u_3: 0.4615 - val_loss: 0.2067 - val_mean_io_u_3: 0.4618
# Epoch 104/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1860 - mean_io_u_3: 0.4615 - val_loss: 0.2061 - val_mean_io_u_3: 0.4618
# Epoch 105/150
# 67/67 [==============================] - 34s 515ms/step - loss: 0.1860 - mean_io_u_3: 0.4615 - val_loss: 0.2061 - val_mean_io_u_3: 0.4618
# Epoch 106/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1863 - mean_io_u_3: 0.4615 - val_loss: 0.2060 - val_mean_io_u_3: 0.4618
# Epoch 107/150
# 67/67 [==============================] - 34s 513ms/step - loss: 0.1850 - mean_io_u_3: 0.4615 - val_loss: 0.2055 - val_mean_io_u_3: 0.4618
# Epoch 108/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1845 - mean_io_u_3: 0.4615 - val_loss: 0.2058 - val_mean_io_u_3: 0.4618
# Epoch 109/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.1859 - mean_io_u_3: 0.4615 - val_loss: 0.2052 - val_mean_io_u_3: 0.4618
# Epoch 110/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1838 - mean_io_u_3: 0.4615 - val_loss: 0.2054 - val_mean_io_u_3: 0.4618
# Epoch 111/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1846 - mean_io_u_3: 0.4615 - val_loss: 0.2051 - val_mean_io_u_3: 0.4618
# Epoch 112/150
# 67/67 [==============================] - 34s 511ms/step - loss: 0.1851 - mean_io_u_3: 0.4615 - val_loss: 0.2051 - val_mean_io_u_3: 0.4618
# Epoch 113/150
# 67/67 [==============================] - 34s 515ms/step - loss: 0.1865 - mean_io_u_3: 0.4615 - val_loss: 0.2045 - val_mean_io_u_3: 0.4618
# Epoch 114/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1857 - mean_io_u_3: 0.4615 - val_loss: 0.2045 - val_mean_io_u_3: 0.4618
# Epoch 115/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.1830 - mean_io_u_3: 0.4615 - val_loss: 0.2045 - val_mean_io_u_3: 0.4618
# Epoch 116/150
# 67/67 [==============================] - 34s 513ms/step - loss: 0.1842 - mean_io_u_3: 0.4615 - val_loss: 0.2042 - val_mean_io_u_3: 0.4618
# Epoch 117/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1839 - mean_io_u_3: 0.4615 - val_loss: 0.2040 - val_mean_io_u_3: 0.4618
# Epoch 118/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.1834 - mean_io_u_3: 0.4615 - val_loss: 0.2043 - val_mean_io_u_3: 0.4618
# Epoch 119/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1824 - mean_io_u_3: 0.4615 - val_loss: 0.2040 - val_mean_io_u_3: 0.4618
# Epoch 120/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1832 - mean_io_u_3: 0.4615 - val_loss: 0.2037 - val_mean_io_u_3: 0.4618
# Epoch 121/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1845 - mean_io_u_3: 0.4615 - val_loss: 0.2035 - val_mean_io_u_3: 0.4618
# Epoch 122/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.1825 - mean_io_u_3: 0.4615 - val_loss: 0.2035 - val_mean_io_u_3: 0.4618
# Epoch 123/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1812 - mean_io_u_3: 0.4615 - val_loss: 0.2034 - val_mean_io_u_3: 0.4618
# Epoch 124/150
# 67/67 [==============================] - 34s 512ms/step - loss: 0.1831 - mean_io_u_3: 0.4615 - val_loss: 0.2031 - val_mean_io_u_3: 0.4618
# Epoch 125/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1817 - mean_io_u_3: 0.4615 - val_loss: 0.2029 - val_mean_io_u_3: 0.4618
# Epoch 126/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.1833 - mean_io_u_3: 0.4615 - val_loss: 0.2027 - val_mean_io_u_3: 0.4618
# Epoch 127/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1828 - mean_io_u_3: 0.4615 - val_loss: 0.2027 - val_mean_io_u_3: 0.4618
# Epoch 128/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1813 - mean_io_u_3: 0.4615 - val_loss: 0.2027 - val_mean_io_u_3: 0.4618
# Epoch 129/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1830 - mean_io_u_3: 0.4615 - val_loss: 0.2024 - val_mean_io_u_3: 0.4618
# Epoch 130/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1833 - mean_io_u_3: 0.4615 - val_loss: 0.2022 - val_mean_io_u_3: 0.4618
# Epoch 131/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.1815 - mean_io_u_3: 0.4615 - val_loss: 0.2020 - val_mean_io_u_3: 0.4618
# Epoch 132/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1822 - mean_io_u_3: 0.4615 - val_loss: 0.2019 - val_mean_io_u_3: 0.4618
# Epoch 133/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1821 - mean_io_u_3: 0.4615 - val_loss: 0.2016 - val_mean_io_u_3: 0.4618
# Epoch 134/150
# 67/67 [==============================] - 34s 512ms/step - loss: 0.1824 - mean_io_u_3: 0.4615 - val_loss: 0.2015 - val_mean_io_u_3: 0.4618
# Epoch 135/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1809 - mean_io_u_3: 0.4615 - val_loss: 0.2020 - val_mean_io_u_3: 0.4618
# Epoch 136/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.1801 - mean_io_u_3: 0.4615 - val_loss: 0.2016 - val_mean_io_u_3: 0.4618
# Epoch 137/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1812 - mean_io_u_3: 0.4615 - val_loss: 0.2010 - val_mean_io_u_3: 0.4618
# Epoch 138/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1810 - mean_io_u_3: 0.4615 - val_loss: 0.2013 - val_mean_io_u_3: 0.4618
# Epoch 139/150
# 67/67 [==============================] - 35s 520ms/step - loss: 0.1809 - mean_io_u_3: 0.4615 - val_loss: 0.2005 - val_mean_io_u_3: 0.4618
# Epoch 140/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1812 - mean_io_u_3: 0.4615 - val_loss: 0.2010 - val_mean_io_u_3: 0.4618
# Epoch 141/150
# 67/67 [==============================] - 34s 514ms/step - loss: 0.1811 - mean_io_u_3: 0.4615 - val_loss: 0.2005 - val_mean_io_u_3: 0.4618
# Epoch 142/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1807 - mean_io_u_3: 0.4615 - val_loss: 0.2002 - val_mean_io_u_3: 0.4618
# Epoch 143/150
# 67/67 [==============================] - 35s 518ms/step - loss: 0.1803 - mean_io_u_3: 0.4615 - val_loss: 0.2003 - val_mean_io_u_3: 0.4618
# Epoch 144/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1811 - mean_io_u_3: 0.4615 - val_loss: 0.2002 - val_mean_io_u_3: 0.4618
# Epoch 145/150
# 67/67 [==============================] - 35s 515ms/step - loss: 0.1795 - mean_io_u_3: 0.4615 - val_loss: 0.2001 - val_mean_io_u_3: 0.4618
# Epoch 146/150
# 67/67 [==============================] - 35s 519ms/step - loss: 0.1815 - mean_io_u_3: 0.4615 - val_loss: 0.1999 - val_mean_io_u_3: 0.4618
# Epoch 147/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1800 - mean_io_u_3: 0.4615 - val_loss: 0.1999 - val_mean_io_u_3: 0.4618
# Epoch 148/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1813 - mean_io_u_3: 0.4615 - val_loss: 0.2000 - val_mean_io_u_3: 0.4618
# Epoch 149/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1789 - mean_io_u_3: 0.4615 - val_loss: 0.1997 - val_mean_io_u_3: 0.4618
# Epoch 150/150
# 67/67 [==============================] - 35s 516ms/step - loss: 0.1790 - mean_io_u_3: 0.4615 - val_loss: 0.1998 - val_mean_io_u_3: 0.4618
#
#
# round: 4 in 20
#
#
# 0.12219934063061487
# activation function: relu
# dropout:  0.12
# data amount: 67
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 67 steps, validate for 13 steps
# Epoch 1/150
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 67/67 [==============================] - 39s 579ms/step - loss: 0.4630 - mean_io_u_4: 0.4617 - val_loss: 0.3612 - val_mean_io_u_4: 0.4618
# Epoch 2/150
# 67/67 [==============================] - 34s 506ms/step - loss: 0.3191 - mean_io_u_4: 0.4615 - val_loss: 0.3200 - val_mean_io_u_4: 0.4618
# Epoch 3/150
# 67/67 [==============================] - 34s 507ms/step - loss: 0.2903 - mean_io_u_4: 0.4615 - val_loss: 0.3004 - val_mean_io_u_4: 0.4618
# Epoch 4/150
# 67/67 [==============================] - 34s 503ms/step - loss: 0.2762 - mean_io_u_4: 0.4615 - val_loss: 0.2884 - val_mean_io_u_4: 0.4618
# Epoch 5/150
# 67/67 [==============================] - 34s 503ms/step - loss: 0.2683 - mean_io_u_4: 0.4615 - val_loss: 0.2781 - val_mean_io_u_4: 0.4618
# Epoch 6/150
# 67/67 [==============================] - 34s 504ms/step - loss: 0.2632 - mean_io_u_4: 0.4615 - val_loss: 0.2727 - val_mean_io_u_4: 0.4618
# Epoch 7/150
# 67/67 [==============================] - 34s 505ms/step - loss: 0.2591 - mean_io_u_4: 0.4615 - val_loss: 0.2666 - val_mean_io_u_4: 0.4618
# Epoch 8/150
# 67/67 [==============================] - 34s 503ms/step - loss: 0.2560 - mean_io_u_4: 0.4615 - val_loss: 0.2628 - val_mean_io_u_4: 0.4618
# Epoch 9/150
# 67/67 [==============================] - 34s 502ms/step - loss: 0.2482 - mean_io_u_4: 0.4615 - val_loss: 0.2595 - val_mean_io_u_4: 0.4618
# Epoch 10/150
# 67/67 [==============================] - 34s 504ms/step - loss: 0.2491 - mean_io_u_4: 0.4615 - val_loss: 0.2548 - val_mean_io_u_4: 0.4618
# Epoch 11/150
# 67/67 [==============================] - 34s 505ms/step - loss: 0.2479 - mean_io_u_4: 0.4615 - val_loss: 0.2526 - val_mean_io_u_4: 0.4618
# Epoch 12/150
# 67/67 [==============================] - 34s 501ms/step - loss: 0.2413 - mean_io_u_4: 0.4615 - val_loss: 0.2493 - val_mean_io_u_4: 0.4618
# Epoch 13/150
# 67/67 [==============================] - 34s 503ms/step - loss: 0.2439 - mean_io_u_4: 0.4615 - val_loss: 0.2480 - val_mean_io_u_4: 0.4618
# Epoch 14/150
# 67/67 [==============================] - 34s 506ms/step - loss: 0.2387 - mean_io_u_4: 0.4615 - val_loss: 0.2445 - val_mean_io_u_4: 0.4618
# Epoch 15/150
# 67/67 [==============================] - 34s 503ms/step - loss: 0.2351 - mean_io_u_4: 0.4615 - val_loss: 0.2426 - val_mean_io_u_4: 0.4618
# Epoch 16/150
# 67/67 [==============================] - 34s 501ms/step - loss: 0.2325 - mean_io_u_4: 0.4615 - val_loss: 0.2414 - val_mean_io_u_4: 0.4618
# Epoch 17/150
# 67/67 [==============================] - 34s 505ms/step - loss: 0.2340 - mean_io_u_4: 0.4615 - val_loss: 0.2391 - val_mean_io_u_4: 0.4618
# Epoch 18/150
# 67/67 [==============================] - 34s 504ms/step - loss: 0.2296 - mean_io_u_4: 0.4615 - val_loss: 0.2384 - val_mean_io_u_4: 0.4618
# Epoch 19/150
# 67/67 [==============================] - 34s 505ms/step - loss: 0.2296 - mean_io_u_4: 0.4615 - val_loss: 0.2361 - val_mean_io_u_4: 0.4618
# Epoch 20/150
# 67/67 [==============================] - 34s 506ms/step - loss: 0.2288 - mean_io_u_4: 0.4615 - val_loss: 0.2356 - val_mean_io_u_4: 0.4618
# Epoch 21/150
# 67/67 [==============================] - 34s 506ms/step - loss: 0.2247 - mean_io_u_4: 0.4615 - val_loss: 0.2343 - val_mean_io_u_4: 0.4618
# Epoch 22/150
# 67/67 [==============================] - 34s 506ms/step - loss: 0.2249 - mean_io_u_4: 0.4615 - val_loss: 0.2336 - val_mean_io_u_4: 0.4618
# Epoch 23/150
# 67/67 [==============================] - 34s 503ms/step - loss: 0.2224 - mean_io_u_4: 0.4615 - val_loss: 0.2324 - val_mean_io_u_4: 0.4618
# Epoch 24/150
# 67/67 [==============================] - 34s 507ms/step - loss: 0.2241 - mean_io_u_4: 0.4615 - val_loss: 0.2314 - val_mean_io_u_4: 0.4618
# Epoch 25/150
# 67/67 [==============================] - 34s 501ms/step - loss: 0.2192 - mean_io_u_4: 0.4615 - val_loss: 0.2306 - val_mean_io_u_4: 0.4618
# Epoch 26/150
# 67/67 [==============================] - 34s 503ms/step - loss: 0.2190 - mean_io_u_4: 0.4615 - val_loss: 0.2299 - val_mean_io_u_4: 0.4618
# Epoch 27/150
# ...
# Epoch 48/150
# 50/50 [==============================] - 26s 512ms/step - loss: 0.1677 - mean_io_u_7: 0.4615 - val_loss: 0.2077 - val_mean_io_u_7: 0.4618
# Epoch 49/150
# 50/50 [==============================] - 25s 508ms/step - loss: 0.1683 - mean_io_u_7: 0.4615 - val_loss: 0.2074 - val_mean_io_u_7: 0.4618
# Epoch 50/150
# 50/50 [==============================] - 25s 508ms/step - loss: 0.1679 - mean_io_u_7: 0.4615 - val_loss: 0.2070 - val_mean_io_u_7: 0.4618
# Epoch 51/150
# 50/50 [==============================] - 25s 510ms/step - loss: 0.1669 - mean_io_u_7: 0.4615 - val_loss: 0.2071 - val_mean_io_u_7: 0.4618
# Epoch 52/150
# 50/50 [==============================] - 25s 510ms/step - loss: 0.1689 - mean_io_u_7: 0.4615 - val_loss: 0.2062 - val_mean_io_u_7: 0.4618
# Epoch 53/150
# 50/50 [==============================] - 26s 511ms/step - loss: 0.1644 - mean_io_u_7: 0.4615 - val_loss: 0.2052 - val_mean_io_u_7: 0.4618
# Epoch 54/150
# 50/50 [==============================] - 25s 507ms/step - loss: 0.1626 - mean_io_u_7: 0.4615 - val_loss: 0.2062 - val_mean_io_u_7: 0.4618
# Epoch 55/150
# 50/50 [==============================] - 25s 506ms/step - loss: 0.1634 - mean_io_u_7: 0.4615 - val_loss: 0.2048 - val_mean_io_u_7: 0.4618
# Epoch 56/150
# 50/50 [==============================] - 25s 509ms/step - loss: 0.1636 - mean_io_u_7: 0.4615 - val_loss: 0.2045 - val_mean_io_u_7: 0.4618
# Epoch 57/150
# 50/50 [==============================] - 26s 511ms/step - loss: 0.1624 - mean_io_u_7: 0.4615 - val_loss: 0.2040 - val_mean_io_u_7: 0.4618
# Epoch 58/150
# 50/50 [==============================] - 25s 509ms/step - loss: 0.1618 - mean_io_u_7: 0.4615 - val_loss: 0.2045 - val_mean_io_u_7: 0.4618
# Epoch 59/150
# 50/50 [==============================] - 25s 503ms/step - loss: 0.1616 - mean_io_u_7: 0.4615 - val_loss: 0.2037 - val_mean_io_u_7: 0.4618
# Epoch 60/150
# 50/50 [==============================] - 25s 505ms/step - loss: 0.1644 - mean_io_u_7: 0.4615 - val_loss: 0.2035 - val_mean_io_u_7: 0.4618
# Epoch 61/150
# 50/50 [==============================] - 25s 509ms/step - loss: 0.1597 - mean_io_u_7: 0.4615 - val_loss: 0.2036 - val_mean_io_u_7: 0.4618
# Epoch 62/150
# 50/50 [==============================] - 26s 512ms/step - loss: 0.1622 - mean_io_u_7: 0.4615 - val_loss: 0.2030 - val_mean_io_u_7: 0.4618
# Epoch 63/150
# 50/50 [==============================] - 25s 506ms/step - loss: 0.1595 - mean_io_u_7: 0.4615 - val_loss: 0.2029 - val_mean_io_u_7: 0.4618
# Epoch 64/150
# 50/50 [==============================] - 26s 510ms/step - loss: 0.1611 - mean_io_u_7: 0.4615 - val_loss: 0.2026 - val_mean_io_u_7: 0.4618
# Epoch 65/150
# 50/50 [==============================] - 25s 506ms/step - loss: 0.1598 - mean_io_u_7: 0.4615 - val_loss: 0.2024 - val_mean_io_u_7: 0.4618
# Epoch 66/150
# 50/50 [==============================] - 25s 509ms/step - loss: 0.1610 - mean_io_u_7: 0.4615 - val_loss: 0.2030 - val_mean_io_u_7: 0.4618
# Epoch 67/150
# 50/50 [==============================] - 26s 511ms/step - loss: 0.1605 - mean_io_u_7: 0.4615 - val_loss: 0.2010 - val_mean_io_u_7: 0.4618
# Epoch 68/150
# 50/50 [==============================] - 25s 505ms/step - loss: 0.1599 - mean_io_u_7: 0.4615 - val_loss: 0.2017 - val_mean_io_u_7: 0.4618
# Epoch 69/150
# 50/50 [==============================] - 26s 511ms/step - loss: 0.1603 - mean_io_u_7: 0.4615 - val_loss: 0.2017 - val_mean_io_u_7: 0.4618
# Epoch 70/150
# 50/50 [==============================] - 25s 508ms/step - loss: 0.1598 - mean_io_u_7: 0.4615 - val_loss: 0.2015 - val_mean_io_u_7: 0.4618
# Epoch 71/150
# 50/50 [==============================] - 25s 507ms/step - loss: 0.1609 - mean_io_u_7: 0.4615 - val_loss: 0.2006 - val_mean_io_u_7: 0.4618
# Epoch 72/150
# 50/50 [==============================] - 26s 512ms/step - loss: 0.1583 - mean_io_u_7: 0.4615 - val_loss: 0.2006 - val_mean_io_u_7: 0.4618
# Epoch 73/150
# 50/50 [==============================] - 26s 511ms/step - loss: 0.1579 - mean_io_u_7: 0.4615 - val_loss: 0.1996 - val_mean_io_u_7: 0.4618
# Epoch 74/150
# 50/50 [==============================] - 26s 512ms/step - loss: 0.1589 - mean_io_u_7: 0.4615 - val_loss: 0.1995 - val_mean_io_u_7: 0.4618
# Epoch 75/150
# 50/50 [==============================] - 25s 504ms/step - loss: 0.1584 - mean_io_u_7: 0.4615 - val_loss: 0.1995 - val_mean_io_u_7: 0.4618
# Epoch 76/150
# 50/50 [==============================] - 26s 512ms/step - loss: 0.1576 - mean_io_u_7: 0.4615 - val_loss: 0.1988 - val_mean_io_u_7: 0.4618
# Epoch 77/150
# 50/50 [==============================] - 25s 507ms/step - loss: 0.1572 - mean_io_u_7: 0.4615 - val_loss: 0.1999 - val_mean_io_u_7: 0.4618
# Epoch 78/150
# 50/50 [==============================] - 26s 510ms/step - loss: 0.1576 - mean_io_u_7: 0.4615 - val_loss: 0.2003 - val_mean_io_u_7: 0.4618
# Epoch 79/150
# 50/50 [==============================] - 25s 507ms/step - loss: 0.1545 - mean_io_u_7: 0.4615 - val_loss: 0.1995 - val_mean_io_u_7: 0.4618
# Epoch 80/150
# 50/50 [==============================] - 25s 508ms/step - loss: 0.1573 - mean_io_u_7: 0.4615 - val_loss: 0.1983 - val_mean_io_u_7: 0.4618
# Epoch 81/150
# 50/50 [==============================] - 26s 510ms/step - loss: 0.1576 - mean_io_u_7: 0.4615 - val_loss: 0.1992 - val_mean_io_u_7: 0.4618
# Epoch 82/150
# 50/50 [==============================] - 25s 507ms/step - loss: 0.1591 - mean_io_u_7: 0.4615 - val_loss: 0.1981 - val_mean_io_u_7: 0.4618
# Epoch 83/150
# 50/50 [==============================] - 25s 508ms/step - loss: 0.1548 - mean_io_u_7: 0.4615 - val_loss: 0.1973 - val_mean_io_u_7: 0.4618
# Epoch 84/150
# 50/50 [==============================] - 25s 506ms/step - loss: 0.1580 - mean_io_u_7: 0.4615 - val_loss: 0.1968 - val_mean_io_u_7: 0.4618
# Epoch 85/150
# 50/50 [==============================] - 25s 509ms/step - loss: 0.1547 - mean_io_u_7: 0.4615 - val_loss: 0.1976 - val_mean_io_u_7: 0.4618
# Epoch 86/150
# 50/50 [==============================] - 25s 506ms/step - loss: 0.1584 - mean_io_u_7: 0.4615 - val_loss: 0.1979 - val_mean_io_u_7: 0.4618
# Epoch 87/150
# 50/50 [==============================] - 25s 506ms/step - loss: 0.1554 - mean_io_u_7: 0.4615 - val_loss: 0.1966 - val_mean_io_u_7: 0.4618
# Epoch 88/150
# 50/50 [==============================] - 28s 563ms/step - loss: 0.1531 - mean_io_u_7: 0.4615 - val_loss: 0.1966 - val_mean_io_u_7: 0.4618
# Epoch 89/150
# 50/50 [==============================] - 26s 516ms/step - loss: 0.1531 - mean_io_u_7: 0.4615 - val_loss: 0.1970 - val_mean_io_u_7: 0.4618
# Epoch 90/150
# 50/50 [==============================] - 25s 507ms/step - loss: 0.1544 - mean_io_u_7: 0.4615 - val_loss: 0.1972 - val_mean_io_u_7: 0.4618
# Epoch 91/150
# 50/50 [==============================] - 25s 510ms/step - loss: 0.1543 - mean_io_u_7: 0.4615 - val_loss: 0.1966 - val_mean_io_u_7: 0.4618
# Epoch 92/150
# 50/50 [==============================] - 25s 508ms/step - loss: 0.1528 - mean_io_u_7: 0.4615 - val_loss: 0.1969 - val_mean_io_u_7: 0.4618
# Epoch 00092: early stopping
#
#
# round: 8 in 20
#
#
# 0.18497178854847662
# activation function: relu
# dropout:  0.18
# data amount: 49
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 49 steps, validate for 9 steps
# Epoch 1/150
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 49/49 [==============================] - 30s 604ms/step - loss: 0.5939 - mean_io_u_8: 0.4625 - val_loss: 0.2429 - val_mean_io_u_8: 0.4618
# Epoch 2/150
# 49/49 [==============================] - 26s 528ms/step - loss: 0.2096 - mean_io_u_8: 0.4615 - val_loss: 0.1968 - val_mean_io_u_8: 0.4618
# Epoch 3/150
# 49/49 [==============================] - 26s 531ms/step - loss: 0.1981 - mean_io_u_8: 0.4615 - val_loss: 0.1898 - val_mean_io_u_8: 0.4618
# Epoch 4/150
# 49/49 [==============================] - 26s 527ms/step - loss: 0.1851 - mean_io_u_8: 0.4615 - val_loss: 0.1840 - val_mean_io_u_8: 0.4618
# Epoch 5/150
# 49/49 [==============================] - 26s 526ms/step - loss: 0.1852 - mean_io_u_8: 0.4615 - val_loss: 0.1826 - val_mean_io_u_8: 0.4618
# Epoch 6/150
# 49/49 [==============================] - 26s 527ms/step - loss: 0.1790 - mean_io_u_8: 0.4615 - val_loss: 0.1822 - val_mean_io_u_8: 0.4618
# Epoch 7/150
# 49/49 [==============================] - 26s 526ms/step - loss: 0.1881 - mean_io_u_8: 0.4615 - val_loss: 0.1859 - val_mean_io_u_8: 0.4618
# Epoch 8/150
# 49/49 [==============================] - 26s 528ms/step - loss: 0.1817 - mean_io_u_8: 0.4615 - val_loss: 0.1876 - val_mean_io_u_8: 0.4618
# Epoch 9/150
# 49/49 [==============================] - 26s 529ms/step - loss: 0.1776 - mean_io_u_8: 0.4615 - val_loss: 0.1821 - val_mean_io_u_8: 0.4618
# Epoch 10/150
# 49/49 [==============================] - 26s 532ms/step - loss: 0.1726 - mean_io_u_8: 0.4615 - val_loss: 0.1832 - val_mean_io_u_8: 0.4618
# Epoch 11/150
# 49/49 [==============================] - 26s 529ms/step - loss: 0.1790 - mean_io_u_8: 0.4615 - val_loss: 0.1841 - val_mean_io_u_8: 0.4618
# Epoch 12/150
# 49/49 [==============================] - 26s 531ms/step - loss: 0.1748 - mean_io_u_8: 0.4615 - val_loss: 0.1836 - val_mean_io_u_8: 0.4618
# Epoch 13/150
# 49/49 [==============================] - 26s 527ms/step - loss: 0.1709 - mean_io_u_8: 0.4615 - val_loss: 0.1756 - val_mean_io_u_8: 0.4618
# Epoch 14/150
# 49/49 [==============================] - 26s 531ms/step - loss: 0.1674 - mean_io_u_8: 0.4615 - val_loss: 0.1685 - val_mean_io_u_8: 0.4618
# Epoch 15/150
# 49/49 [==============================] - 26s 525ms/step - loss: 0.1710 - mean_io_u_8: 0.4615 - val_loss: 0.1792 - val_mean_io_u_8: 0.4618
# Epoch 16/150
# 49/49 [==============================] - 26s 527ms/step - loss: 0.1620 - mean_io_u_8: 0.4615 - val_loss: 0.1669 - val_mean_io_u_8: 0.4618
# Epoch 17/150
# 49/49 [==============================] - 26s 531ms/step - loss: 0.1614 - mean_io_u_8: 0.4615 - val_loss: 0.1686 - val_mean_io_u_8: 0.4618
# Epoch 18/150
# 49/49 [==============================] - 26s 524ms/step - loss: 0.1600 - mean_io_u_8: 0.4615 - val_loss: 0.1597 - val_mean_io_u_8: 0.4618
# Epoch 19/150
# 49/49 [==============================] - 26s 525ms/step - loss: 0.1622 - mean_io_u_8: 0.4615 - val_loss: 0.1635 - val_mean_io_u_8: 0.4618
# Epoch 20/150
# 49/49 [==============================] - 26s 529ms/step - loss: 0.1674 - mean_io_u_8: 0.4615 - val_loss: 0.1557 - val_mean_io_u_8: 0.4618
# Epoch 21/150
# 49/49 [==============================] - 26s 529ms/step - loss: 0.1591 - mean_io_u_8: 0.4615 - val_loss: 0.1636 - val_mean_io_u_8: 0.4618
# Epoch 22/150
# 49/49 [==============================] - 26s 525ms/step - loss: 0.1574 - mean_io_u_8: 0.4615 - val_loss: 0.1544 - val_mean_io_u_8: 0.4618
# Epoch 23/150
# 49/49 [==============================] - 26s 529ms/step - loss: 0.1514 - mean_io_u_8: 0.4615 - val_loss: 0.1524 - val_mean_io_u_8: 0.4618
# Epoch 24/150
# 49/49 [==============================] - 26s 525ms/step - loss: 0.1608 - mean_io_u_8: 0.4615 - val_loss: 0.1609 - val_mean_io_u_8: 0.4618
# Epoch 25/150
# 49/49 [==============================] - 26s 526ms/step - loss: 0.1581 - mean_io_u_8: 0.4615 - val_loss: 0.1750 - val_mean_io_u_8: 0.4618
# Epoch 26/150
# 49/49 [==============================] - 26s 527ms/step - loss: 0.1598 - mean_io_u_8: 0.4615 - val_loss: 0.1715 - val_mean_io_u_8: 0.4618
# Epoch 27/150
# 49/49 [==============================] - 26s 528ms/step - loss: 0.1613 - mean_io_u_8: 0.4615 - val_loss: 0.1612 - val_mean_io_u_8: 0.4618
# Epoch 28/150
# 49/49 [==============================] - 26s 526ms/step - loss: 0.1627 - mean_io_u_8: 0.4615 - val_loss: 0.1674 - val_mean_io_u_8: 0.4618
# Epoch 00028: early stopping
#
#
# round: 9 in 20
#
#
# 0.29348105286835047
# activation function: relu
# dropout:  0.29
# data amount: 69
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 69 steps, validate for 13 steps
# Epoch 1/150
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 69/69 [==============================] - 41s 594ms/step - loss: 0.5016 - mean_io_u_9: 0.4618 - val_loss: 0.2503 - val_mean_io_u_9: 0.4618
# Epoch 2/150
# 69/69 [==============================] - 36s 520ms/step - loss: 0.2148 - mean_io_u_9: 0.4615 - val_loss: 0.2093 - val_mean_io_u_9: 0.4618
# Epoch 3/150
# 69/69 [==============================] - 35s 513ms/step - loss: 0.2006 - mean_io_u_9: 0.4615 - val_loss: 0.1988 - val_mean_io_u_9: 0.4618
# Epoch 4/150
# 69/69 [==============================] - 36s 518ms/step - loss: 0.1943 - mean_io_u_9: 0.4615 - val_loss: 0.2124 - val_mean_io_u_9: 0.4618
# Epoch 5/150
# 69/69 [==============================] - 36s 523ms/step - loss: 0.1917 - mean_io_u_9: 0.4615 - val_loss: 0.1985 - val_mean_io_u_9: 0.4618
# Epoch 6/150
# 69/69 [==============================] - 36s 523ms/step - loss: 0.1857 - mean_io_u_9: 0.4615 - val_loss: 0.1985 - val_mean_io_u_9: 0.4618
# Epoch 7/150
# 69/69 [==============================] - 36s 524ms/step - loss: 0.1867 - mean_io_u_9: 0.4615 - val_loss: 0.2004 - val_mean_io_u_9: 0.4618
# Epoch 8/150
# 69/69 [==============================] - 36s 522ms/step - loss: 0.1829 - mean_io_u_9: 0.4615 - val_loss: 0.1997 - val_mean_io_u_9: 0.4618
# Epoch 9/150
# 69/69 [==============================] - 36s 526ms/step - loss: 0.1786 - mean_io_u_9: 0.4615 - val_loss: 0.2020 - val_mean_io_u_9: 0.4618
# Epoch 10/150
# 69/69 [==============================] - 36s 524ms/step - loss: 0.1799 - mean_io_u_9: 0.4615 - val_loss: 0.2007 - val_mean_io_u_9: 0.4618
# Epoch 00010: early stopping
#
#
# round: 10 in 20
#
#
# 0.2350894866035438
# activation function: elu
# dropout:  0.24
# data amount: 84
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `tf.data.Dataset`.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 84 steps, validate for 16 steps
# Epoch 1/150
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 84/84 [==============================] - 50s 590ms/step - loss: 0.4028 - mean_io_u_10: 0.4619 - val_loss: 0.2084 - val_mean_io_u_10: 0.4618
# Epoch 2/150
# 84/84 [==============================] - 44s 519ms/step - loss: 0.1994 - mean_io_u_10: 0.4615 - val_loss: 0.1842 - val_mean_io_u_10: 0.4618
# Epoch 3/150
# 84/84 [==============================] - 43s 512ms/step - loss: 0.1831 - mean_io_u_10: 0.4615 - val_loss: 0.1717 - val_mean_io_u_10: 0.4618
# Epoch 4/150
# 84/84 [==============================] - 43s 515ms/step - loss: 0.1756 - mean_io_u_10: 0.4615 - val_loss: 0.1669 - val_mean_io_u_10: 0.4618
# Epoch 5/150
# 84/84 [==============================] - 43s 512ms/step - loss: 0.1714 - mean_io_u_10: 0.4615 - val_loss: 0.1575 - val_mean_io_u_10: 0.4618
# Epoch 6/150
# 84/84 [==============================] - 43s 510ms/step - loss: 0.1711 - mean_io_u_10: 0.4615 - val_loss: 0.1557 - val_mean_io_u_10: 0.4618
# Epoch 7/150
# 84/84 [==============================] - 43s 513ms/step - loss: 0.1679 - mean_io_u_10: 0.4615 - val_loss: 0.1600 - val_mean_io_u_10: 0.4618
# Epoch 8/150
# 84/84 [==============================] - 43s 514ms/step - loss: 0.1949 - mean_io_u_10: 0.4621 - val_loss: 0.1953 - val_mean_io_u_10: 0.4618
# Epoch 9/150
# 84/84 [==============================] - 43s 512ms/step - loss: 0.2077 - mean_io_u_10: 0.4615 - val_loss: 0.1861 - val_mean_io_u_10: 0.4618
# Epoch 10/150
# 43/84 [==============>...............] - ETA: 15s - loss: 0.1756 - mean_io_u_10: 0.4615

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training', 'validation'])
plt.title('loss')
plt.xlabel('Epoch')

# %%
x_train_val, y_train_val = next(batch_generator(img_val_list, color_label_val_list, color_id_map,classes_cc, [5,4], 1, training= False))


img_predicted = model.predict(x_train_val)[0]
target = maskes_to_labels(y_train_val[0]).astype(np.uint8)

print(img_predicted.shape)

y_train_label = maskes_to_labels(img_predicted).astype(np.uint8)
compare_img(x_train_val[0], target, 'Image', 'CityScape labels')
compare_img(x_train_val[0], y_train_label, 'Image', 'CityScape labels')

# %%
print(f'image: {x_train_val[0].dtype}')
print(f'predictions: {y_train_label.dtype}')

# %%
img_mask = cv2.addWeighted(y_train_label, 0.5, x_train_val[0], 0.5, 0)
img_target = cv2.addWeighted(target, 0.5, x_train_val[0], 0.5, 0)

compare_img(img_mask, img_target)

# %%
#model.save(f'../seg_models/u-net_mc_4_30.h5')

# %%
#model = load_model('../seg_models/u-net_mc_4_30.h5')

# %% [markdown]
# ## Test Monte Carlo, uncertenty

# %%
x_train_val, y_train_val = next(batch_generator(img_val_list, color_label_val_list, color_id_map,classes_cc, [1], 1, training= False))
img_predicted = model.predict(x_train_val)[0]

#model = model that have the prediction
#T number of test rounds
# returns mean prediction and uncertenty 
def predictions_and_uncetrenty(model, T, img):
    
    # shape: (T, (H, W), C)
    predictions = np.array([model.predict(img) for _ in range(T)])
    
    # shape: ((H, W), C)
    prediction_probabilities = np.mean(predictions, axis=tuple(range(img.ndim-2)))
   
    # shape: (H, W)
    #prediction_variances = np.apply_along_axis(predictive_entropy, axis=2, arr=prediction_probabilities)
    prediction_std = np.std(predictions, axis=tuple(range(img.ndim-2)))
    prediction_mask = (prediction_probabilities==prediction_probabilities.max(axis=2, keepdims=1)).astype(np.uint8)
    prediction_std = prediction_std * prediction_mask
    prediction_std = np.amax(prediction_std, axis=2)
    
    prediction_mean = prediction_probabilities * prediction_mask
    prediction_mean = np.amax(prediction_mean, axis=2)
    return prediction_mask, prediction_mean ,prediction_std
    
    
# prob - predictions probability for each class(c). Shape(N, C)
# returns - Shape(N)
def predictive_entropy(prob):
    return -1 * np.sum(np.log(prob) * prob, axis=1) 

target = maskes_to_labels(y_train_val[0]).astype(np.uint8)
predicted_target,_ ,prediction_std = predictions_and_uncetrenty(model, 100, x_train_val)
print(prediction_std.shape)
#print(img_predicted.shape)

y_train_label = maskes_to_labels(img_predicted).astype(np.uint8)
uncertenty_predction = maskes_to_labels(predicted_target).astype(np.uint8)


compare_img(x_train_val[0], target, 'Image', 'CityScape labels')
compare_img(x_train_val[0], y_train_label, 'Image', 'CityScape labels')
compare_img(uncertenty_predction, y_train_label, 'Monte carlo predictiom', 'normal prediction')
compare_img(uncertenty_predction, prediction_std, 'Monte carlo predictiom', 'variance')

# %%
print(prediction_std.mean()) #

# %%
# rounds: 5 mean var: 0.0035581593
# rounds: 10 sum variance: 1188 
# rounds: 100 sum variance: 1317
# rounds: 500 sum variance: 1331
import scipy.stats
"""
create a general model for base line
"""
def print_normal_dist(model, img, target, N):
     
    target_labels = maskes_to_labels(target[0]).astype(np.uint8)
    print(target_labels.shape)
    print(img.shape)
    
    img_and_target_labels = cv2.addWeighted(target_labels, 0.5, img[0], 0.5, 0)
    
    #do monte carlo predictions
    predicted_target, prediction_mean ,prediction_std = predictions_and_uncetrenty(model, N, img)

    
    # 2d array of mean of certenty 
    predicted_mean = np.mean(prediction_mean)#np.amax(predicted_target, axis=2)
    
    #make classes to rgb image with right color
    predction_labels = maskes_to_labels(predicted_target).astype(np.uint8)
    img_prediction = cv2.addWeighted(predction_labels, 0.5, img[0], 0.5, 0)
    
    compare_img(img_and_target_labels, img_prediction, 'Target', f'Monte Carlo {N} rounds')
    
    #plot normal distribution
    x_min = 0.0
    x_max = 1.0
    
    mean = predicted_mean.mean()
    std = prediction_std.mean()
    
    print(f'mean: {mean}')
    print(f'std: {std}')
    
    fig = plt.figure(figsize=(16, 5))
    a = fig.add_subplot(1,2,1)
    
    x = np.linspace(x_min, x_max, 100)
    y = scipy.stats.norm.pdf(x, mean, std)
    plt.plot(x,y, color='black')
    plt.grid()
    plt.xlim(x_min, x_max)
    plt.ylim(0.5)
    #plt.show()
    
    a = fig.add_subplot(1, 2, 2)
    imgplot = plt.imshow(prediction_std)
    a.set_title("standard derivation in image")
    

    imgplot = plt.show()
    a.set_title('Normal distribution of all pixels')
    
predicted_target_2d = np.amax(predicted_target, axis=2)
print(predicted_target_2d.mean())
print_normal_dist(model, x_train_val, y_train_val, 5)

# %%
print_normal_dist(model, x_train_val, y_train_val, 10)

# %%
print_normal_dist(model, x_train_val, y_train_val, 100)

# %%
print_normal_dist(model, x_train_val, y_train_val, 500)
